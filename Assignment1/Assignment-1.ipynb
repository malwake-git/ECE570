# %% [markdown]
# # ECE 570: Assignment 1
#
# ## **Instructions**
# 1. Please follow the thread in Piazza for detailed usage of Google Colab.
# 2. All submissions should be uploaded to Gradescope as a PDF version of your current Jupyter notebook. In this assignment you only need to submit section 3, 4, 5, and 6.
# 3. Have fun!

# %% [markdown]
# ## 1. Background
# In this assignment, we are trying to do simple sentiment analysis. Sentiment analysis is the process of detecting positive or negative sentiment in text. It’s often used by businesses to detect sentiment in social data, gauge brand reputation, and understand customers.
#
# The dataset we will be using is called the [***Stanford Sentiment Treebank***](https://nlp.stanford.edu/sentiment/code.html). This dataset is collected from movie reviews on *Rotten Tomatoes* and includes over 20k sentences. All reviews were later re-organized as distinct phrases with a label as a number between 0.0 and 1.0. Labels can later be divided in to five intervals [0, 0.2], (0.2, 0.4], (0.4, 0.6], (0.6, 0.8], (0.8, 1.0] which means very negative, negative, neutral, positive, and very positive, respectively.
#
# The dataset we are using in this assignment is a subset of Stanford Sentiment Treebank and consists of only **400 phrases**. For simplicity, the dataset only contains extreme sentiments; half of them are extremely positive reviews (have corresponding range (0.9, 1.0]), and the other half are extremely negative reviews (have corresponding range [0.0, 0.1]).
#
# In machine learning (ML), the process of optimizing the model given some dataset is known as *training* or *learning*---thus the data used during training is merely called the *training data* (e.g., historicial reviews). This is analagous to a student seeing worked-out problems in class to help understand a concept.  However, after the model has been trained, it will be used to predict on new data (e.g., new reviews)---this is what is often called *test data*. This process is analagous to a student taking a test and requires them to understand the concepts rather than just memorizing the problems worked-out in class. We will cover these concepts in more detail later on in the lectures.
#
# To *simulate* this process and evaluate your model *as if it was deployed*, we will split the dataset into two parts: a training dataset (50%) and test dataset (50%), where both have an equal number of positive and negative reviews.
#
# Your job is to manually construct a simple function that determines whether a single phrase (input) has a positive or negative sentiment (output/return value). You are only allowed to see and optimize using the **training dataset** (simulating model training in ML), but we provide a function that performs a final evaluation of your model on the **testing dataset** (simulating the model being deployed in the real world).
#
# *Note: We obfuscate (i.e., make secret) the testing function because in the real world, you won't know what the new data will look like.*

# %% [markdown]
# ## 2. Mounting your google drive on Colab
# Since colab is running on a remote server on Google, you need to mount your google drive on Colab to serve as a 'local directory' to your coding environment. Luckily, it is as simple as two steps! Try to run this block and follow the instructions that got popped out.
#
# Note: This part is not necessary if you are using your own Python environment or other remote python environment.

# %%
from google.colab import drive 
drive.mount('/content/drive')

# %% [markdown]
# ## 3. Load data (10/100 points)
# Now, we need to load the data from the "train.txt" and "test.txt" file. Please change the location for **dir_root** in the following code block to where you saved all your files.
#
# The train dataset is stored in the "train.txt" file which stores 100 positive phrases and 100 negative phrases. Each line in the file is consist of a phrase and the corresponding sentiment positive(1) or negative(-1) followed by a separation mark '|'.
#
# Tip: It is helpful and sometimes necessary to have a separate folder for each assignment!

# %%
import os                                                                       # for better path controls
#########################        YOUR CODE        ######################### 
import pandas as pd
dir_root = 'D:\Jupyter\ECE570\Assignment-1'    # change this root directory
#########################      END YOUR CODE      #########################
train_dir = os.path.join(dir_root, 'train.txt')                                 # locate the train.txt file

# %%
# use built-in function "open" to read files 
#  and use the "with" syntax to automatically close the file after the block
with open(train_dir, 'r') as f:
    train_lines = f.readlines()

# construct two lists to store phrases and labels seperately
train_data, train_label = [], []
for line in train_lines:
    line_sec = line.split("|", -1)
    train_data.append(line_sec[0])
    train_label.append(int(line_sec[1]))

# preview some data here
preview = 10                 # feel free to toggle this number to see more/less data
for i, (phrase, label) in enumerate(zip(train_data[:preview], train_label[:preview])):
    print(f'Phrase {i:03} \"{phrase}\" has the sentiment {label}')
# Out:
# Phrase 000 "Astonishingly skillful and moving" has the sentiment 1
# Phrase 001 "are incredibly beautiful to look at" has the sentiment 1
# Phrase 002 "as the most magical and most fun family fare of this or any recent holiday season" has the sentiment 1
# Phrase 003 "It shows that some studios firmly believe that people have lost the ability to think and will forgive any shoddy product as long as there 's a little girl-on-girl action ." has the sentiment -1
# Phrase 004 "Will assuredly rank as one of the cleverest , most deceptively amusing comedies of the year ." has the sentiment 1
# Phrase 005 "disintegrates into a dreary , humorless soap opera" has the sentiment -1
# Phrase 006 "The editing is chaotic , the photography grainy and badly focused , the writing unintentionally hilarious , the direction unfocused ," has the sentiment -1
# Phrase 007 "The film is often filled with a sense of pure wonderment and excitement not often seen in today 's cinema du sarcasm" has the sentiment 1
# Phrase 008 "is as appalling as any ` comedy ' to ever spill from a projector 's lens" has the sentiment -1
# Phrase 009 "... could easily be called the best Korean film of 2002 ." has the sentiment 1

# %% [markdown]
# ## 4. Classifier (80/100 points)
# Please fill in code in the provided skeleton for the function `sentiment_analysis` which has the following structure:
# * Input: a single string `phrase`
# * Output/Return value: an integer `-1` or `1`. `-1` stands for negative sentiment and `1` stands for positive sentiment
#
# This task is similar to the hand-crafted knowledge phase of AI in which you are manually creating rules or performing manual computation by using your intuition and looking at some examples. You should not use any ML packages for this assignment (simple Python code should be enough).
#
# Notes:
# 1. To receive full credit, your training accuracy must be greater than 60%. (After some effort, Prof. Inouye was able to get 66.5%. Can you do better?)
# 2. Your code should be less than **50 lines without importing any additional packages** (i.e, this assignment does not require you to perform any complicated model analysis).  Only 10-20 lines is likely required if written concisely.
# 3. You can view all the training phrases by opening file *'train.txt'* in the provided zip file. This may help understand what could be used in your function.
# 4. Throughout the design of your algorithm, **you should only have access to the train dataset** stored in "train.txt". The test dataset stored in 'test.npy' is used in the next evaluation section but you should not look at this (see discussion above). Again, you can think that train dataset is what we would actually have to learn from (like course materials and lectures) while test is new data that simulates real-world posts (where we wouldn’t usually know the true labels).
#
# You might find the following hints helpful (not required to use them):
# 1. The Python keyword `in` can be used to determine if a string is within another string. e.g., `'ece' in 'hello ece 570'` would evaluate to `True`.
# 2. The `lower()` or `upper()` methods of string can be helpful, e.g., if `a = 'HeLlo'` then `print(a.lower())` would print `hello`.
# 3. A partial frequency table for all words in the training dataset is given as the follow:
#
# Word | # positive | # negative | # total
# --- | --- | --- | ---
# best|12|0|12
# i|0|11|11
# are|9|1|10
# most|9|1|10
# bad|0|10|10
# at|2|6|8
# his|7|1|8
# has|5|3|8
# about|2|6|8
# have|1|6|7
# from|2|4|6
# worst|0|6|6
# does|2|4|6
# brilliant|6|0|6
# films|6|0|6
# any|1|4|5
# enough|1|4|5
# what|4|1|5
# work|5|0|5
# great|4|1|5
# time|1|4|5
# or|1|3|4
# some|1|3|4
# will|3|1|4
# sense|3|1|4
# cinema|3|1|4
# comedy|1|3|4
# just|1|3|4
# first|4|0|4
# masterpiece|3|1|4
# my|0|4|4
# want|1|3|4
# if|0|4|4
# something|3|1|4
# story|3|1|4
# love|4|0|4
# filmmaking|2|2|4
# their|4|0|4
# when|0|4|4
# than|1|3|4
# look|1|2|3
# recent|3|0|3
# product|0|3|3
# into|0|3|3
# hilarious|2|1|3
# often|3|0|3
# easily|3|0|3
# performances|3|0|3
# deserves|3|0|3

# %%
def train_analysis():
    result_word = []
    result_score = []
    
    for i in range(len(data.Word)):
        if data.positive[i] > data.negative[i]:
            result_word.append(data.Word[i])
            result_score.append(1)

        elif data.positive[i] < data.negative[i]:
            result_word.append(data.Word[i])
            result_score.append(-1)
        else:
            result_word.append(data.Word[i])
            result_score.append(0)
    
    return result_word,result_score

# %%
import pandas as pd

data = pd.read_csv('freq_table.csv')

# %%
def sentiment_analysis(phrase):
    """
    sentiment_analysis function determines whether a phrase is positive (1) or negative (-1).

    :param1(string) phrase: a single phrase in the format of string
    :return(int)          : 1 if the phrase is postive or -1 if the phrase is negative
    """ 
    #########################        YOUR CODE        ######################### 
    low_phrase = phrase.lower()
    score = 0

    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    
    words = ['the','he','be','to','of','and','a','in','that','have','I','it','for','not','on','with','he','as','you','do','at','this','but','his','by','from','they','we','say','her','she','or','an','will','my','one','all','would','there','their','what','so','up','out','if','about','who','get','which','go','me','when','make','can','like','time','no','just','him']
    
    for x in low_phrase:
        if x in punctuations:
            low_phrase = low_phrase.replace(x, "")
    
    
    #result_word,result_score = train_analysis()
    res = low_phrase.split()
    for x in res:
        print("words = ",x)
        if x in words:
            res.remove(x)
    print("\n",res,"\n")
    for i in res:
        #for l in range(len(z.Word)):
        for l in range(len(data.Word)):
            
            if i == data.Word[l]:
                
                if data.positive[l] > data.negative[l]:
                    #if (len(i) > 3):
                    print("word: ",data.Word[l],"positive: ",data.positive[l])
                        #data.positive[l] = data.positive[l] + 1
                        #score = score + 1
                        #if data.positive[l] > 5:
                         #   score = score + 5
                        #else:
                    score = score + data.positive[l]
                    break
                elif data.negative[l] > data.positive[l]:
                    #if (len(i) > 3):
                    print("word: ",data.Word[l],"negative: ",data.negative[l])
                        #data.negative[l] = data.negative[l] + 1
                        #score = score - 1
                        #if data.negative[l] > 5:
                         #   score = score - 5
                        #else:
                    score = score - data.negative[l]
                        
                    break
        #if i in result_word:
            #score = score + result_score[result_word.index(i)]
            
    if score < 0:
        
        for i in res:
            for k in range(len(data.Word)):
                if i == data.Word[k]:
            #print(data.Word[s],"\n")
                    data.negative[k] = data.negative[k] + 1
                    data.total[k] = data.total[k] + 1
                    break
        
            if i != data.Word[k]:
                print(i)
                data.loc[len(data)] = {'Word': i,'positive': 0,'negative': 1,'total': 1}
                #data = data.append({'Word': i,'positive': 0,'negative': 1,'total': 1}, ignore_index = True)
                #l = l + 1
                #data.Word[l] = i
                #data.negative[l] = 1
                #data.positive[l] = 0
                #data.total[l] = 1
            
        
        return -1
            
    elif score > 0:
        for i in res:
            for k in range(len(data.Word)):
                if i == data.Word[k]:
            #print(data.Word[s],"\n")
                    data.positive[k] = data.positive[k] + 1
                    data.total[k] = data.total[k] + 1
                    break
                    
            if i != data.Word[k]:
                print(i)
                data.loc[len(data)] = {'Word': i,'positive': 1,'negative': 0,'total': 1}
               
            #data = data.append({'Word': i,'positive': 1,'negative': 0,'total': 1})
                
                #data.Word[l] = i
                #data.positive[l] = 1
                #data.negative[l] = 0
                #data.total[l] = 1
            
        return 1     # change this line and add lines above
    
    
    
    else:
        print("score = ",score)
        return 0
    #########################      END YOUR CODE      ######################### 


def evaluate(func, data, label):
    score = 0
    
    for x, y in zip(data, label):
        score += (func(x) == y)
    return score/len(data)

train_acc = evaluate(sentiment_analysis, train_data, train_label)
print(f"Your method has a training accuracy of {train_acc*100}%")
# Out:
# words =  astonishingly
# words =  skillful
# words =  and
#
#  ['astonishingly', 'skillful', 'moving']
#
# score =  0
# words =  are
# words =  incredibly
# words =  beautiful
# words =  to
# words =  at
#
#  ['are', 'incredibly', 'beautiful', 'look']
#
# word:  are positive:  9
# word:  look negative:  2
# incredibly
# beautiful
# words =  as
# words =  most
# words =  magical
# words =  and
# words =  fun
# words =  family
# words =  fare
# words =  of
# words =  or
# words =  recent
# words =  holiday
# words =  season
#
#  ['the', 'most', 'magical', 'most', 'fun', 'family', 'fare', 'this', 'any', 'recent', 'holiday', 'season']
#
# word:  most positive:  9
# word:  most positive:  9
# word:  any negative:  4
# word:  recent positive:  3
# the
# magical
# fun
# family
# fare
# this
# holiday
# season
# words =  it
# words =  that
# words =  studios
# words =  firmly
# words =  believe
# words =  that
# words =  have
# words =  the
# words =  to
# words =  and
# words =  forgive
# words =  any
# words =  shoddy
# words =  product
# words =  as
# words =  as
# words =  s
# words =  a
# words =  girlongirl
# words =  action
#
#  ['shows', 'some', 'studios', 'firmly', 'believe', 'people', 'lost', 'ability', 'think', 'will', 'forgive', 'any', 'shoddy', 'product', 'long', 'there', 's', 'little', 'girlongirl', 'action']
#
# word:  some negative:  3
# word:  will positive:  3
# word:  any negative:  4
# word:  product negative:  3
# shows
# studios
# firmly
# believe
# people
# lost
# ability
# think
# forgive
# shoddy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# long
# there
# s
# little
# girlongirl
# action
# words =  will
# words =  rank
# words =  as
# words =  of
# words =  cleverest
# words =  most
# words =  deceptively
# words =  amusing
# words =  comedies
# words =  of
# words =  year
#
#  ['assuredly', 'rank', 'one', 'the', 'cleverest', 'most', 'deceptively', 'amusing', 'comedies', 'the', 'year']
#
# word:  the positive:  1
# word:  most positive:  11
# word:  the positive:  1
# assuredly
# rank
# one
# cleverest
# deceptively
# amusing
# comedies
# year
# words =  disintegrates
# words =  into
# words =  a
# words =  humorless
# words =  soap
# words =  opera
#
#  ['disintegrates', 'into', 'dreary', 'humorless', 'soap', 'opera']
#
# word:  into negative:  3
# disintegrates
# dreary
# humorless
# soap
# opera
# words =  the
# words =  is
# words =  chaotic
# words =  the
# words =  grainy
# words =  and
# words =  focused
# words =  the
# words =  unintentionally
# words =  hilarious
# words =  the
# words =  unfocused
#
#  ['editing', 'is', 'chaotic', 'photography', 'grainy', 'badly', 'focused', 'writing', 'unintentionally', 'hilarious', 'direction', 'unfocused']
#
# word:  hilarious positive:  2
# editing
# is
# chaotic
# photography
# grainy
# badly
# focused
# writing
# unintentionally
# direction
# unfocused
# words =  the
# words =  is
# words =  often
# words =  filled
# words =  with
# words =  sense
# words =  of
# words =  wonderment
# words =  and
# words =  not
# words =  seen
# words =  in
# words =  s
# words =  cinema
# words =  du
# words =  sarcasm
#
#  ['film', 'is', 'often', 'filled', 'a', 'sense', 'pure', 'wonderment', 'excitement', 'often', 'seen', 'today', 's', 'cinema', 'du', 'sarcasm']
#
# word:  is positive:  1
# word:  often positive:  3
# word:  sense positive:  3
# word:  often positive:  3
# word:  s negative:  1
# word:  cinema positive:  3
# film
# filled
# a
# pure
# wonderment
# excitement
# seen
# today
# du
# sarcasm
# words =  is
# words =  as
# words =  as
# words =  `
# words =  comedy
# words =  to
# words =  spill
# words =  from
# words =  projector
# words =  s
# words =  lens
#
#  ['is', 'appalling', 'any', '`', 'comedy', 'ever', 'spill', 'a', 'projector', 's', 'lens']
#
# word:  is positive:  2
# word:  any negative:  5
# word:  comedy negative:  3
# word:  a positive:  1
# appalling
# `
# ever
# spill
# projector
# lens
# words =  could
# words =  easily
# words =  be
# words =  the
# words =  korean
# words =  film
# words =  of
#
#  ['could', 'easily', 'called', 'best', 'korean', 'film', '2002']
#
# word:  easily positive:  3
# word:  best positive:  12
# word:  film positive:  1
# could
# called
# korean
# 2002
# words =  like
# words =  with
# words =  legs
# words =  and
# words =  that
#
#  ['puppies', 'broken', 'legs', 'butterflies', 'die']
#
# score =  0
# words =  the
# words =  national
# words =  lampoon
# words =  film
#
#  ['worst', 'national', 'lampoon', 'film']
#
# word:  worst negative:  6
# word:  film positive:  2
# national
# lampoon
# words =  need
# words =  to
# words =  invented
# words =  to
# words =  exactly
# words =  how
# words =  bad
# words =  it
#
#  ['need', 'be', 'invented', 'describe', 'exactly', 'how', 'bad', 'is']
#
# word:  bad negative:  10
# word:  is positive:  2
# need
# be
# invented
# describe
# exactly
# how
# words =  this
# words =  of
# words =  wertmuller
# words =  s
# words =  1975
# words =  eroticomedy
# words =  might
# words =  just
# words =  the
# words =  husbandandwife
# words =  disaster
# words =  since
# words =  john
# words =  and
#
#  ['remake', 'lina', 'wertmuller', 's', '1975', 'eroticomedy', 'might', 'be', 'biggest', 'husbandandwife', 'disaster', 'since', 'john']
#
# word:  s negative:  2
# word:  be negative:  1
# remake
# lina
# wertmuller
# 1975
# eroticomedy
# might
# biggest
# husbandandwife
# disaster
# since
# john
# words =  mesmerizing
# words =  performances
#
#  ['mesmerizing', 'performances']
#
# word:  performances positive:  3
# mesmerizing
# words =  chelsea
# words =  walls
# words =  deserves
# words =  a
#
#  ['chelsea', 'walls', 'deserves', 'medal']
#
# word:  deserves positive:  3
# chelsea
# walls
# medal
# words =  unlikable
# words =  uninteresting
# words =  unfunny
# words =  and
# words =  utterly
# words =  inept
#
#  ['unlikable', 'uninteresting', 'unfunny', 'completely', 'utterly', 'inept']
#
# score =  0
# words =  populated
# words =  by
# words =  pathetic
# words =  starving
# words =  and
# words =  artistes
#
#  ['populated', 'whiny', 'pathetic', 'starving', 'untalented', 'artistes']
#
# score =  0
# words =  does
# words =  a
# words =  so
# words =  and
# words =  of
# words =  as
# words =  one
# words =  along
#
#  ['does', 'film', 'graceless', 'devoid', 'merit', 'this', 'come', 'along']
#
# word:  does negative:  4
# word:  film positive:  2
# word:  this positive:  1
# graceless
# devoid
# merit
# come
# along
# words =  draws
# words =  out
# words =  best
# words =  from
# words =  large
# words =  cast
# words =  in
# words =  articulated
# words =  portrayals
# words =  that
# words =  subtle
# words =  and
# words =  expressive
# words =  they
# words =  sustain
# words =  the
# words =  flights
# words =  in
# words =  s
# words =  dialogue
#
#  ['draws', 'best', 'his', 'large', 'cast', 'beautifully', 'articulated', 'portrayals', 'are', 'subtle', 'so', 'expressive', 'can', 'sustain', 'the', 'poetic', 'flights', 'burdette', 's', 'dialogue']
#
# word:  best positive:  13
# word:  his positive:  7
# word:  are positive:  10
# word:  the positive:  3
# word:  s negative:  3
# draws
# large
# cast
# beautifully
# articulated
# portrayals
# subtle
# so
# expressive
# can
# sustain
# poetic
# flights
# burdette
# dialogue
# words =  is
# words =  a
# words =  movie
#
#  ['is', 'brilliant', 'movie']
#
# word:  brilliant positive:  6
# movie
# words =  it
# words =  nt
# words =  even
# words =  have
# words =  virtue
# words =  of
# words =  mindless
# words =  violence
# words =  to
# words =  up
# words =  tedium
# words =  of
# words =  its
# words =  generational
# words =  bonding
#
#  ['does', 'nt', 'even', 'the', 'virtue', 'enough', 'mindless', 'violence', 'break', 'the', 'tedium', 'all', 'its', 'generational', 'bonding']
#
# word:  does negative:  5
# word:  the positive:  4
# word:  enough negative:  4
# word:  the positive:  4
# nt
# even
# virtue
# mindless
# violence
# break
# tedium
# all
# its
# generational
# bonding
# words =  the
# words =  swooping
# words =  aerial
# words =  shots
# words =  are
# words =  breathtaking
#
#  ['magnificent', 'swooping', 'aerial', 'shots', 'are', 'breathtaking']
#
# word:  are positive:  11
# magnificent
# swooping
# aerial
# shots
# breathtaking
# words =  have
# words =  much
# words =  charisma
# words =  that
# words =  d
# words =  be
# words =  to
# words =  to
# words =  reading
# words =  the
# words =  book
#
#  ['so', 'much', 'charisma', 'you', 'd', 'happy', 'listen', 'them', 'reading', 'phone', 'book']
#
# word:  so positive:  1
# much
# charisma
# you
# d
# happy
# listen
# them
# reading
# phone
# book
# words =  disgusted
#
#  ['disgusted']
#
# score =  0
# words =  most
# words =  breathtakingly
# words =  designed
#
#  ['most', 'breathtakingly', 'designed']
#
# word:  most positive:  12
# breathtakingly
# designed
# words =  s
# words =  perfect
# words =  it
# words =  also
# words =  the
# words =  s
# words =  sweetest
# words =  movie
#
#  ['s', 'perfect', 's', 'also', 'year', 's', 'sweetest', 'movie']
#
# word:  s negative:  3
# word:  s negative:  3
# word:  year positive:  1
# word:  s negative:  3
# word:  movie positive:  1
# perfect
# also
# sweetest
# words =  the
# words =  is
# words =  funny
# words =  smart
# words =  visually
# words =  inventive
# words =  and
# words =  of
# words =  alive
#
#  ['movie', 'is', 'funny', 'smart', 'visually', 'inventive', 'most', 'all', 'alive']
#
# word:  is positive:  3
# word:  most positive:  13
# word:  all negative:  1
# funny
# smart
# visually
# inventive
# alive
# words =  watched
# words =  the
# words =  insanity
# words =  of
# words =  such
# words =  thing
# words =  with
# words =  disbelief
#
#  ['watched', 'brainless', 'insanity', 'no', 'such', 'thing', 'mounting', 'disbelief']
#
# score =  0
# words =  run
# words =  for
# words =  lives
#
#  ['run', 'your', 'lives']
#
# score =  0
# words =  as
# words =  masterfully
# words =  made
# words =  one
#
#  ['a', 'masterfully', 'made']
#
# score =  0
# words =  between
# words =  them
# words =  de
# words =  niro
# words =  and
# words =  make
# words =  the
# words =  savory
# words =  and
# words =  guilty
# words =  pleasure
# words =  of
# words =  a
# words =  movie
# words =  season
#
#  ['between', 'them', 'de', 'niro', 'murphy', 'showtime', 'most', 'savory', 'hilarious', 'guilty', 'pleasure', 'many', 'recent', 'movie', 'season']
#
# word:  them positive:  1
# word:  most positive:  14
# word:  hilarious positive:  3
# word:  recent positive:  4
# word:  movie positive:  2
# word:  season positive:  1
# between
# de
# niro
# murphy
# showtime
# savory
# guilty
# pleasure
# many
# words =  amazingly
# words =  evocative
# words =  film
#
#  ['amazingly', 'evocative', 'film']
#
# score =  0
# words =  one
# words =  those
# words =  comedies
# words =  that
# words =  seem
# words =  like
# words =  bad
# words =  idea
# words =  from
# words =  one
#
#  ['of', 'those', 'comedies', 'just', 'seem', 'a', 'bad', 'idea', 'frame']
#
# word:  comedies positive:  1
# word:  just negative:  3
# word:  bad negative:  11
# of
# those
# seem
# idea
# frame
# words =  this
# words =  is
# words =  hopeless
#
#  ['movie', 'is', 'hopeless']
#
# word:  movie positive:  3
# word:  is positive:  4
# hopeless
# words =  we
# words =  a
# words =  bad
# words =  bad
# words =  movie
#
#  ['have', 'bad', 'bad', 'bad', 'movie']
#
# word:  have negative:  6
# word:  bad negative:  12
# word:  bad negative:  12
# word:  bad negative:  12
# word:  movie positive:  4
# words =  has
# words =  all
# words =  scenic
# words =  appeal
# words =  of
# words =  cesspool
#
#  ['has', 'the', 'scenic', 'appeal', 'a', 'cesspool']
#
# word:  has positive:  5
# word:  the positive:  4
# word:  a negative:  2
# scenic
# appeal
# cesspool
# words =  a
# words =  and
# words =  movie
#
#  ['cumbersome', 'clicheridden', 'movie']
#
# word:  movie positive:  4
# cumbersome
# clicheridden
# words =  starts
# words =  out
# words =  spirals
# words =  downward
# words =  and
# words =  to
# words =  bottom
# words =  of
# words =  pool
# words =  with
# words =  utterly
# words =  incompetent
# words =  conclusion
#
#  ['starts', 'mediocre', 'spirals', 'downward', 'thuds', 'the', 'bottom', 'the', 'pool', 'an', 'utterly', 'incompetent', 'conclusion']
#
# word:  the positive:  5
# word:  the positive:  5
# starts
# mediocre
# spirals
# downward
# thuds
# bottom
# pool
# an
# utterly
# incompetent
# conclusion
# words =  is
# words =  well
# words =  plotted
# words =  visually
# words =  striking
# words =  and
# words =  with
# words =  complex
# words =  characters
# words =  who
# words =  never
# words =  what
# words =  first
# words =  appear
#
#  ['is', 'well', 'plotted', 'visually', 'striking', 'filled', 'enjoyably', 'complex', 'characters', 'are', 'never', 'they', 'first', 'appear']
#
# word:  is positive:  5
# word:  visually positive:  1
# word:  filled positive:  1
# word:  are positive:  12
# word:  first positive:  4
# well
# plotted
# striking
# enjoyably
# complex
# characters
# never
# they
# appear
# words =  zero
# words =  compelling
# words =  storyline
#
#  ['zero', 'compelling', 'storyline']
#
# score =  0
# words =  can
# words =  describe
# words =  as
# words =  sounding
# words =  and
# words =  feeling
# words =  like
# words =  other
# words =  film
# words =  in
# words =  history
#
#  ['honestly', 'describe', 'looking', 'sounding', 'simply', 'feeling', 'no', 'other', 'film', 'recent', 'history']
#
# word:  describe negative:  1
# word:  recent positive:  5
# honestly
# looking
# sounding
# simply
# feeling
# no
# other
# history
# words =  it
# words =  dull
# words =  spiritless
# words =  silly
# words =  and
# words =  an
# words =  blast
# words =  of
# words =  mayhem
# words =  going
# words =  nowhere
# words =  fast
#
#  ['s', 'dull', 'spiritless', 'silly', 'monotonous', 'ultraloud', 'blast', 'pointless', 'mayhem', 'going', 'nowhere', 'fast']
#
# word:  s negative:  6
# dull
# spiritless
# silly
# monotonous
# ultraloud
# blast
# pointless
# mayhem
# going
# nowhere
# fast
# words =  abandons
# words =  all
# words =  of
# words =  historical
# words =  context
# words =  and
# words =  off
# words =  into
# words =  a
# words =  soap
# words =  about
# words =  ups
# words =  and
# words =  of
# words =  heavy
# words =  breathing
# words =  between
# words =  the
# words =  artists
#
#  ['abandons', 'pretense', 'creating', 'historical', 'context', 'waltzes', 'off', 'into', 'hectic', 'soap', 'ups', 'downs', 'the', 'heavy', 'breathing', 'between', 'the', 'two', 'artists']
#
# word:  into negative:  4
# word:  soap negative:  1
# word:  the positive:  7
# word:  between positive:  1
# word:  the positive:  7
# abandons
# pretense
# creating
# historical
# context
# waltzes
# off
# hectic
# ups
# downs
# heavy
# breathing
# two
# artists
# words =  five
# words =  contemporary
# words =  individuals
# words =  a
# words =  masterpiece
#
#  ['five', 'contemporary', 'individuals', 'psychological', 'masterpiece']
#
# word:  masterpiece positive:  3
# five
# contemporary
# individuals
# psychological
# words =  men
# words =  in
# words =  ii
# words =  achieves
# words =  ultimate
# words =  insignificance
#
#  ['men', 'black', 'ii', 'achieves', 'ultimate', 'insignificance']
#
# score =  0
# words =  an
# words =  demonstration
# words =  of
# words =  unsalvageability
# words =  of
# words =  movie
# words =  saddled
# words =  with
# words =  amateurish
# words =  screenplay
#
#  ['excruciating', 'demonstration', 'the', 'unsalvageability', 'a', 'movie', 'saddled', 'an', 'amateurish', 'screenplay']
#
# word:  the positive:  9
# word:  movie positive:  5
# word:  an positive:  1
# excruciating
# demonstration
# unsalvageability
# saddled
# amateurish
# screenplay
# words =  fails
# words =  so
# words =  on
# words =  conventional
# words =  level
#
#  ['fails', 'fundamentally', 'every', 'conventional', 'level']
#
# score =  0
# words =  wellmeaning
#
#  ['wellmeaning']
#
# score =  0
# words =  a
# words =  relentless
# words =  and
# words =  in
# words =  downbeat
# words =  darkness
#
#  ['triumph', 'relentless', 'beautiful', 'its', 'downbeat', 'darkness']
#
# word:  beautiful positive:  1
# word:  its negative:  1
# score =  0
# words =  it
# words =  unapologetically
# words =  dumb
#
#  ['is', 'unapologetically', 'dumb']
#
# word:  is positive:  6
# unapologetically
# dumb
# words =  unfunny
# words =  and
# words =  any
# words =  sense
# words =  of
# words =  to
# words =  affection
# words =  for
# words =  characters
# words =  the
# words =  hudlin
# words =  comedy
# words =  relies
# words =  on
# words =  humor
# words =  ethnic
# words =  slurs
#
#  ['unfunny', 'lacking', 'any', 'sense', 'commitment', 'or', 'affection', 'its', 'characters', 'reginald', 'hudlin', 'comedy', 'relies', 'toilet', 'humor', 'ethnic', 'slurs']
#
# word:  any negative:  6
# word:  sense positive:  4
# word:  or negative:  3
# word:  its negative:  1
# word:  characters positive:  1
# word:  comedy negative:  4
# unfunny
# lacking
# commitment
# affection
# reginald
# hudlin
# relies
# toilet
# humor
# ethnic
# slurs
# words =  brilliant
# words =  documentary
#
#  ['brilliant', 'documentary']
#
# word:  brilliant positive:  7
# documentary
# words =  watching
# words =  this
# words =  nearly
# words =  provoked
# words =  me
# words =  take
# words =  my
# words =  life
#
#  ['watching', 'film', 'nearly', 'provoked', 'to', 'take', 'own', 'life']
#
# word:  film positive:  3
# watching
# nearly
# provoked
# to
# take
# own
# life
# words =  see
# words =  this
# words =  of
# words =  again
#
#  ['see', 'piece', 'crap', 'again']
#
# score =  0
# words =  ll
# words =  be
# words =  entertained
# words =  getting
# words =  hit
# words =  by
# words =  bus
#
#  ['ll', 'more', 'entertained', 'getting', 'hit', 'a', 'bus']
#
# word:  a positive:  3
# ll
# more
# entertained
# getting
# hit
# bus
# words =  fabulous
#
#  ['fabulous']
#
# score =  0
# words =  this
# words =  film
#
#  ['ludicrous', 'film']
#
# word:  film positive:  4
# ludicrous
# words =  otherwise
# words =  appalling
# words =  and
# words =  creepy
#
#  ['otherwise', 'appalling', 'downright', 'creepy']
#
# word:  appalling negative:  1
# otherwise
# downright
# creepy
# words =  i
# words =  still
# words =  want
# words =  my
# words =  back
#
#  ['i', 'still', 'want', 'money', 'back']
#
# word:  i negative:  11
# word:  want negative:  3
# still
# money
# back
# words =  directs
# words =  and
# words =  around
# words =  his
# words =  s
# words =  sappier
# words =  elements
# words =  and
# words =  off
# words =  the
# words =  s
# words =  buildup
# words =  with
# words =  assuredness
# words =  for
# words =  firsttimer
#
#  ['directs', 'edits', 'around', 'screenplay', 's', 'sappier', 'elements', 'sustains', 'off', 'hook', 's', 'buildup', 'remarkable', 'assuredness', 'a', 'firsttimer']
#
# word:  screenplay positive:  1
# word:  s negative:  7
# word:  off positive:  1
# word:  s negative:  7
# word:  a positive:  4
# directs
# edits
# around
# sappier
# elements
# sustains
# hook
# buildup
# remarkable
# assuredness
# firsttimer
# words =  flog
# words =  the
# words =  horse
# words =  of
# words =  as
# words =  it
# words =  an
# words =  how
# words =  about
# words =  us
# words =  by
# words =  something
# words =  new
#
#  ['flog', 'dead', 'horse', 'surprise', 'if', 'were', 'obligation', 'how', 'surprising', 'us', 'trying', 'something', 'new']
#
# word:  if negative:  4
# word:  how negative:  1
# word:  something positive:  3
# flog
# dead
# horse
# surprise
# were
# obligation
# surprising
# us
# trying
# new
# words =  corny
# words =  schmaltzy
# words =  and
#
#  ['corny', 'schmaltzy', 'predictable']
#
# score =  0
# words =  is
# words =  such
# words =  a
# words =  selfassured
# words =  directorial
# words =  debut
# words =  that
# words =  s
# words =  hard
# words =  to
# words =  what
# words =  praise
# words =  first
#
#  ['is', 'such', 'dazzlingly', 'selfassured', 'directorial', 'debut', 'it', 's', 'hard', 'know', 'to', 'praise', 'first']
#
# word:  is positive:  7
# word:  s negative:  9
# word:  to positive:  1
# word:  first positive:  5
# such
# dazzlingly
# selfassured
# directorial
# debut
# it
# hard
# know
# praise
# words =  is
# words =  a
# words =  work
# words =  of
#
#  ['is', 'daring', 'work', 'genius']
#
# word:  is positive:  8
# word:  work positive:  5
# daring
# genius
# words =  the
# words =  s
# words =  worst
# words =  cinematic
# words =  tragedies
#
#  ['year', 's', 'worst', 'cinematic', 'tragedies']
#
# word:  s negative:  9
# word:  worst negative:  7
# cinematic
# tragedies
# words =  ladles
# words =  on
# words =  local
# words =  flavour
# words =  with
# words =  hugely
# words =  enjoyable
# words =  film
# words =  about
# words =  times
# words =  clashing
# words =  cultures
# words =  and
# words =  pleasures
# words =  of
# words =  wellmade
# words =  pizza
#
#  ['ladles', 'the', 'local', 'flavour', 'a', 'hugely', 'enjoyable', 'film', 'changing', 'times', 'clashing', 'cultures', 'the', 'pleasures', 'a', 'wellmade', 'pizza']
#
# word:  the positive:  10
# word:  a positive:  4
# word:  film positive:  5
# word:  the positive:  10
# word:  a positive:  4
# ladles
# local
# flavour
# hugely
# enjoyable
# changing
# times
# clashing
# cultures
# pleasures
# wellmade
# pizza
# words =  a
# words =  of
# words =  films
# words =  like
# words =  should
# words =  be
#
#  ['model', 'what', 'films', 'this', 'should', 'like']
#
# word:  what positive:  4
# word:  films positive:  6
# model
# should
# like
# words =  there
# words =  not
# words =  character
# words =  in
# words =  movie
# words =  with
# words =  shred
# words =  of
# words =  not
# words =  event
# words =  that
# words =  believable
# words =  not
# words =  confrontation
# words =  that
# words =  not
# words =  not
# words =  moment
# words =  that
# words =  not
#
#  ['is', 'a', 'character', 'the', 'movie', 'a', 'shred', 'plausibility', 'an', 'event', 'is', 'believable', 'a', 'confrontation', 'is', 'staged', 'a', 'moment', 'is', 'false']
#
# word:  is positive:  9
# word:  a positive:  6
# word:  the positive:  12
# word:  movie positive:  6
# word:  a positive:  6
# word:  an positive:  2
# word:  is positive:  9
# word:  a positive:  6
# word:  is positive:  9
# word:  a positive:  6
# word:  is positive:  9
# character
# shred
# plausibility
# event
# believable
# confrontation
# staged
# moment
# false
# words =  pointless
# words =  tasteless
# words =  and
#
#  ['pointless', 'tasteless', 'idiotic']
#
# word:  pointless negative:  1
# tasteless
# idiotic
# words =  feels
# words =  empty
# words =  and
# words =  like
# words =  a
# words =  wafer
# words =  without
# words =  the
#
#  ['feels', 'empty', 'unsatisfying', 'swallowing', 'communion', 'wafer', 'without', 'wine']
#
# score =  0
# words =  a
# words =  unpredictable
# words =  hilarious
# words =  comedy
#
#  ['delightfully', 'unpredictable', 'hilarious', 'comedy']
#
# word:  hilarious positive:  4
# word:  comedy negative:  5
# delightfully
# unpredictable
# words =  lively
# words =  and
# words =  adventure
#
#  ['lively', 'enjoyable', 'adventure']
#
# word:  enjoyable positive:  1
# lively
# adventure
# words =  the
# words =  itself
# words =  seems
# words =  to
# words =  been
# words =  made
# words =  under
# words =  the
# words =  of
#
#  ['movie', 'itself', 'seems', 'have', 'been', 'made', 'under', 'influence', 'rohypnol']
#
# word:  movie positive:  7
# word:  have negative:  7
# score =  0
# words =  the
# words =  stays
# words =  in
# words =  picture
# words =  is
# words =  a
# words =  story
# words =  terrifically
# words =  told
# words =  by
# words =  man
# words =  who
# words =  it
#
#  ['kid', 'stays', 'the', 'picture', 'is', 'great', 'story', 'terrifically', 'told', 'the', 'man', 'wrote']
#
# word:  the positive:  13
# word:  is positive:  13
# word:  great positive:  4
# word:  story positive:  3
# word:  the positive:  13
# kid
# stays
# picture
# terrifically
# told
# man
# wrote
# words =  deserves
# words =  an
# words =  nomination
#
#  ['deserves', 'oscar', 'nomination']
#
# word:  deserves positive:  4
# oscar
# nomination
# words =  psychological
# words =  masterpiece
#
#  ['psychological', 'masterpiece']
#
# word:  psychological positive:  1
# word:  masterpiece positive:  4
# words =  its
# words =  lackluster
# words =  gear
# words =  of
# words =  blandness
#
#  ['its', 'lackluster', 'gear', 'emotional', 'blandness']
#
# word:  its negative:  2
# lackluster
# gear
# emotional
# blandness
# words =  a
# words =  of
# words =  series
# words =  you
# words =  love
# words =  it
# words =  probably
# words =  want
# words =  to
# words =  it
#
#  ['fan', 'the', 'series', 'll', 'love', 'and', 'probably', 'want', 'see', 'twice']
#
# word:  the positive:  15
# word:  ll positive:  1
# word:  love positive:  4
# word:  want negative:  4
# fan
# series
# and
# probably
# see
# twice
# words =  these
# words =  flicks
# words =  are
# words =  just
# words =  damn
# words =  good
# words =  is
# words =  nt
# words =  it
#
#  ['these', 'flicks', 'are', 'that', 'damn', 'good', 'is', 'nt', 'great']
#
# word:  are positive:  13
# word:  is positive:  14
# word:  nt negative:  1
# word:  great positive:  5
# these
# flicks
# that
# damn
# good
# words =  is
# words =  what
# words =  from
# words =  john
# words =  carpenter
# words =  s
# words =  ghosts
# words =  of
# words =  and
# words =  the
# words =  in
# words =  words
# words =  about
# words =  bad
# words =  a
# words =  you
# words =  likely
# words =  to
# words =  all
#
#  ['is', 'comes', 'taking', 'john', 'carpenter', 's', 'ghosts', 'mars', 'eliminating', 'beheadings', 'other', 'words', 'as', 'bad', 'film', 're', 'likely', 'see', 'year']
#
# word:  is positive:  15
# word:  john negative:  1
# word:  s negative:  10
# word:  other positive:  1
# word:  bad negative:  15
# word:  film positive:  6
# word:  see positive:  1
# word:  year negative:  2
# comes
# taking
# carpenter
# ghosts
# mars
# eliminating
# beheadings
# words
# as
# re
# likely
# words =  rich
# words =  in
# words =  gorgeously
# words =  shot
# words =  and
# words =  acted
#
#  ['rich', 'detail', 'gorgeously', 'shot', 'beautifully', 'acted']
#
# word:  beautifully positive:  1
# rich
# detail
# gorgeously
# shot
# acted
# words =  home
# words =  movie
# words =  is
# words =  a
# words =  treasure
# words =  and
# words =  well
# words =  worth
# words =  your
# words =  time
#
#  ['home', 'movie', 'is', 'sweet', 'treasure', 'something', 'well', 'worth', 'your']
#
# word:  movie positive:  7
# word:  is positive:  15
# word:  something positive:  3
# word:  well positive:  1
# home
# sweet
# treasure
# worth
# your
# words =  a
# words =  dumb
# words =  and
# words =  horror
# words =  film
#
#  ['dull', 'dumb', 'derivative', 'horror', 'film']
#
# word:  dull negative:  1
# word:  dumb positive:  1
# word:  film positive:  6
# derivative
# horror
# words =  but
# words =  s
# words =  nice
# words =  is
# words =  that
# words =  s
# words =  a
# words =  intelligence
# words =  that
# words =  the
#
#  ['what', 's', 'nice', 'is', 'there', 's', 'casual', 'intelligence', 'permeates', 'script']
#
# word:  what positive:  5
# word:  s negative:  11
# word:  is positive:  16
# word:  there negative:  1
# word:  s negative:  11
# nice
# casual
# intelligence
# permeates
# script
# words =  a
# words =  piece
#
#  ['brilliant', 'piece']
#
# word:  brilliant positive:  8
# piece
# words =  s
# words =  funny
# words =  and
# words =  and
# words =  pretty
# words =  damned
# words =  wonderful
# words =  all
# words =  once
#
#  ['s', 'funny', 'human', 'really', 'pretty', 'damned', 'wonderful', 'at', 'once']
#
# word:  s negative:  13
# word:  funny positive:  1
# word:  at negative:  6
# human
# really
# pretty
# damned
# wonderful
# once
# words =  s
# words =  a
# words =  that
# words =  so
# words =  that
# words =  viewing
# words =  ca
# words =  nt
# words =  possibly
# words =  be
#
#  ['s', 'movie', 'accomplishes', 'much', 'one', 'viewing', 'ca', 'nt', 'possibly', 'enough']
#
# word:  s negative:  14
# word:  movie positive:  8
# word:  much positive:  1
# word:  one positive:  1
# word:  enough negative:  5
# accomplishes
# viewing
# ca
# possibly
# words =  s
# words =  probably
# words =  not
# words =  to
# words =  such
# words =  a
# words =  film
#
#  ['s', 'probably', 'easy', 'make', 'such', 'worthless', 'film']
#
# word:  s negative:  15
# word:  probably positive:  1
# word:  such positive:  1
# word:  film positive:  7
# easy
# make
# worthless
# words =  represents
# words =  everything
# words =  wrong
# words =  with
# words =  film
# words =  as
# words =  commodified
# words =  soldout
# words =  concept
# words =  on
# words =  american
# words =  filmmaking
# words =  scene
#
#  ['represents', 'everything', 'wrong', 'independent', 'film', 'a', 'commodified', 'soldout', 'concept', 'the', 'american', 'filmmaking', 'scene']
#
# word:  film positive:  7
# word:  a positive:  10
# word:  the positive:  16
# represents
# everything
# wrong
# independent
# commodified
# soldout
# concept
# american
# scene
# words =  disgusted
# words =  with
# words =  lazy
# words =  material
# words =  and
# words =  finished
# words =  product
# words =  s
# words =  unshapely
# words =  look
#
#  ['disgusted', 'the', 'lazy', 'material', 'the', 'finished', 'product', 's', 'unshapely', 'look']
#
# word:  the positive:  17
# word:  the positive:  17
# word:  product negative:  4
# word:  s negative:  16
# disgusted
# lazy
# material
# finished
# unshapely
# words =  it
# words =  brilliant
#
#  ['s', 'brilliant']
#
# word:  s negative:  16
# word:  brilliant positive:  9
# words =  their
# words =  is
# words =  fantastic
#
#  ['work', 'is', 'fantastic']
#
# word:  work positive:  6
# word:  is positive:  16
# fantastic
# words =  for
# words =  its
# words =  technical
# words =  virtuosity
# words =  the
# words =  is
# words =  so
# words =  in
# words =  and
# words =  pedagogy
# words =  that
# words =  s
# words =  enough
# words =  to
# words =  one
# words =  for
# words =  day
# words =  when
# words =  can
# words =  longer
# words =  handle
# words =  the
# words =  of
#
#  ['all', 'its', 'technical', 'virtuosity', 'film', 'is', 'mired', 'juvenile', 'nearxenophobic', 'pedagogy', 'it', 's', 'enough', 'make', 'pine', 'day', 'godard', 'no', 'longer', 'handle', 'the', 'rigors', 'filmmaking']
#
# word:  its negative:  3
# word:  film positive:  8
# word:  is positive:  17
# word:  it positive:  1
# word:  s negative:  17
# word:  enough negative:  6
# word:  make negative:  1
# word:  no positive:  1
# word:  the positive:  19
# word:  filmmaking positive:  3
# technical
# virtuosity
# mired
# juvenile
# nearxenophobic
# pedagogy
# pine
# day
# godard
# longer
# handle
# rigors
# words =  refreshing
# words =  to
# words =  a
# words =  that
# words =  its
# words =  oldfashioned
# words =  themes
# words =  and
# words =  the
# words =  comes
# words =  out
# words =  like
# words =  wholly
# words =  original
#
#  ['refreshing', 'see', 'movie', 'embraces', 'its', 'oldfashioned', 'themes', 'in', 'process', 'comes', 'looking', 'something', 'wholly', 'original']
#
# word:  movie positive:  8
# word:  its negative:  3
# word:  comes negative:  1
# word:  looking positive:  1
# word:  something positive:  4
# refreshing
# embraces
# oldfashioned
# themes
# in
# process
# wholly
# original
# words =  imagine
# words =  anybody
# words =  ever
# words =  being
# words =  ``
# words =  in
# words =  mood
# words =  to
# words =  a
# words =  as
# words =  and
# words =  as
# words =  grey
# words =  zone
#
#  ['imagine', 'anybody', 'ever', 'being', '``', 'the', 'mood', 'view', 'movie', 'harrowing', 'painful', 'the', 'grey', 'zone']
#
# word:  ever negative:  1
# word:  the positive:  20
# word:  movie positive:  9
# word:  the positive:  20
# imagine
# anybody
# being
# ``
# mood
# view
# harrowing
# painful
# grey
# zone
# words =  indeed
# words =  almost
# words =  never
# words =  is
# words =  such
# words =  highwattage
# words =  brainpower
# words =  coupled
# words =  with
# words =  acting
# words =  and
# words =  exquisite
# words =  unfakable
# words =  sense
# words =  of
#
#  ['indeed', 'almost', 'never', 'is', 'such', 'highwattage', 'brainpower', 'coupled', 'pitchperfect', 'acting', 'an', 'exquisite', 'unfakable', 'sense', 'cinema']
#
# word:  never positive:  1
# word:  is positive:  18
# word:  an positive:  3
# word:  sense positive:  4
# word:  cinema positive:  4
# indeed
# almost
# highwattage
# brainpower
# coupled
# pitchperfect
# acting
# exquisite
# unfakable
# words =  turned
# words =  out
# words =  212
# words =  hours
# words =  of
# words =  excruciatingly
# words =  tedious
# words =  cinema
# words =  that
# words =  an
# words =  in
# words =  making
# words =  water
# words =  torture
# words =  seem
# words =  appealing
#
#  ['turned', 'nearly', '212', 'hours', 'unfocused', 'excruciatingly', 'tedious', 'cinema', 'half', 'hour', 'starts', 'making', 'water', 'torture', 'seem', 'appealing']
#
# word:  nearly positive:  1
# word:  unfocused positive:  1
# word:  cinema positive:  5
# word:  starts positive:  1
# word:  seem negative:  1
# turned
# 212
# hours
# excruciatingly
# tedious
# half
# hour
# making
# water
# torture
# appealing
# words =  funniest
# words =  movie
#
#  ['funniest', 'movie']
#
# word:  movie positive:  10
# funniest
# words =  fastmoving
# words =  and
# words =  film
#
#  ['fastmoving', 'remarkable', 'film']
#
# word:  remarkable negative:  1
# word:  film positive:  9
# fastmoving
# words =  an
# words =  futuristic
# words =  thrillernoir
# words =  minority
# words =  report
# words =  twists
# words =  the
# words =  of
# words =  around
# words =  a
# words =  story
# words =  delivering
# words =  a
# words =  pulse
# words =  intensifying
# words =  escapist
# words =  adventure
# words =  of
# words =  first
# words =  order
#
#  ['exhilarating', 'futuristic', 'thrillernoir', 'minority', 'report', 'twists', 'best', 'technology', 'around', 'gripping', 'story', 'delivering', 'riveting', 'pulse', 'intensifying', 'escapist', 'adventure', 'the', 'first', 'order']
#
# word:  best positive:  14
# word:  around negative:  1
# word:  story positive:  4
# word:  adventure positive:  1
# word:  the positive:  22
# word:  first positive:  6
# exhilarating
# futuristic
# thrillernoir
# minority
# report
# twists
# technology
# gripping
# delivering
# riveting
# pulse
# intensifying
# escapist
# order
# words =  with
# words =  story
# words =  that
# words =  touch
# words =  anyone
# words =  regardless
# words =  of
# words =  familiarity
# words =  with
# words =  sport
#
#  ['a', 'story', 'could', 'touch', 'anyone', 'regardless', 'their', 'familiarity', 'the', 'sport']
#
# word:  a positive:  11
# word:  story positive:  5
# word:  could positive:  1
# word:  their positive:  4
# word:  the positive:  23
# touch
# anyone
# regardless
# familiarity
# sport
# words =  all
# words =  performances
# words =  are
# words =  top
# words =  notch
#
#  ['the', 'performances', 'are', 'top', 'notch']
#
# word:  the positive:  24
# word:  performances positive:  4
# word:  are positive:  14
# top
# notch
# words =  it
# words =  me
# words =  the
# words =  abandon
# words =  all
# words =  of
# words =  good
# words =  movie
# words =  ye
# words =  who
# words =  here
#
#  ['makes', 'say', 'obvious', 'abandon', 'hope', 'a', 'good', 'movie', 'ye', 'enter', 'here']
#
# word:  a positive:  12
# word:  good positive:  1
# word:  movie positive:  11
# makes
# say
# obvious
# abandon
# hope
# ye
# enter
# here
# words =  is
# words =  overkill
# words =  to
# words =  highest
# words =  degree
#
#  ['is', 'overkill', 'the', 'highest', 'degree']
#
# word:  is positive:  19
# word:  the positive:  25
# overkill
# highest
# degree
# words =  horribly
# words =  depressing
# words =  and
#
#  ['horribly', 'depressing']
#
# score =  0
# words =  an
# words =  irritating
# words =  comedy
# words =  about
# words =  vacuous
# words =  people
#
#  ['incredibly', 'irritating', 'comedy', 'thoroughly', 'vacuous', 'people']
#
# word:  incredibly positive:  1
# word:  comedy negative:  6
# word:  people negative:  1
# irritating
# thoroughly
# vacuous
# words =  easily
# words =  one
# words =  the
# words =  films
# words =  of
# words =  year
#
#  ['easily', 'best', 'films', 'of', 'the', 'year']
#
# word:  easily positive:  4
# word:  best positive:  15
# word:  films positive:  7
# word:  of negative:  1
# word:  the positive:  26
# word:  year negative:  3
# words =  brilliantly
# words =  constructed
# words =  work
#
#  ['brilliantly', 'constructed', 'work']
#
# word:  work positive:  7
# brilliantly
# constructed
# words =  as
# words =  grant
# words =  says
# words =  repeatedly
# words =  throughout
# words =  the
# words =  `
# words =  lovely
# words =  brilliant
#
#  ['hugh', 'grant', 'says', 'repeatedly', 'throughout', 'movie', '`', 'lovely', 'brilliant']
#
# word:  movie positive:  12
# word:  ` negative:  1
# word:  brilliant positive:  9
# hugh
# grant
# says
# repeatedly
# throughout
# lovely
# words =  fails
# words =  to
# words =  his
# words =  a
# words =  character
# words =  worth
# words =  rooting
# words =  for
# words =  worth
# words =  rooting
# words =  against
# words =  for
# words =  matter
#
#  ['fails', 'give', 'audience', 'single', 'character', 'worth', 'rooting', 'or', 'worth', 'rooting', 'against', 'that', 'matter']
#
# word:  character positive:  1
# word:  worth positive:  1
# word:  or negative:  4
# word:  worth positive:  1
# word:  that positive:  1
# score =  0
# words =  and
# words =  era
# words =  is
# words =  recreated
# words =  with
# words =  affection
# words =  scored
# words =  to
# words =  with
# words =  tasty
# words =  boogaloo
# words =  beats
#
#  ['the', 'era', 'is', 'recreated', 'obvious', 'affection', 'scored', 'perfection', 'some', 'tasty', 'boogaloo', 'beats']
#
# word:  the positive:  27
# word:  is positive:  20
# word:  obvious positive:  1
# word:  affection negative:  1
# word:  some negative:  4
# era
# recreated
# scored
# perfection
# tasty
# boogaloo
# beats
# words =  a
# words =  for
# words =  shines
# words =  through
# words =  each
# words =  frame
#
#  ['love', 'films', 'shines', 'through', 'each', 'frame']
#
# word:  love positive:  5
# word:  films positive:  8
# word:  frame negative:  1
# shines
# through
# each
# words =  unlikable
#
#  ['unlikable']
#
# score =  0
# words =  is
# words =  repeated
# words =  at
# words =  four
# words =  times
# words =  every
# words =  joke
# words =  is
# words =  repeated
# words =  at
# words =  annoying
# words =  is
# words =  nt
# words =  it
#
#  ['is', 'repeated', 'least', 'four', 'times', 'every', 'joke', 'is', 'repeated', 'least', 'annoying', 'is', 'nt']
#
# word:  is positive:  21
# word:  times positive:  1
# word:  is positive:  21
# word:  is positive:  21
# word:  nt negative:  2
# repeated
# least
# four
# every
# joke
# annoying
# words =  ranks
# words =  with
# words =  worst
#
#  ['ranks', 'the', 'worst']
#
# word:  the positive:  28
# word:  worst negative:  8
# ranks
# words =  the
# words =  wondrous
# words =  of
# words =  hollywood
# words =  fantasies
#
#  ['most', 'wondrous', 'all', 'hollywood', 'fantasies']
#
# word:  most positive:  15
# word:  all positive:  2
# wondrous
# hollywood
# fantasies
# words =  one
# words =  the
# words =  romantic
# words =  comedies
# words =  of
# words =  past
# words =  decade
#
#  ['greatest', 'romantic', 'comedies', 'of', 'the', 'past', 'decade']
#
# word:  the positive:  29
# greatest
# romantic
# past
# decade
# words =  have
# words =  admit
# words =  i
# words =  walked
# words =  out
# words =  runteldat
#
#  ['to', 'admit', 'i', 'walked', 'of', 'runteldat']
#
# word:  to positive:  2
# word:  i negative:  12
# word:  of positive:  2
# admit
# walked
# runteldat
# words =  the
# words =  master
# words =  of
# words =  chase
# words =  sequence
# words =  returns
# words =  with
# words =  chase
# words =  to
# words =  all
#
#  ['modern', 'master', 'the', 'chase', 'sequence', 'returns', 'a', 'chase', 'end', 'chases']
#
# word:  the positive:  30
# word:  a positive:  13
# modern
# master
# chase
# sequence
# returns
# end
# chases
# words =  does
# words =  nt
# words =  quite
# words =  do
# words =  to
# words =  awfulness
# words =  of
# words =  movie
# words =  for
# words =  comes
# words =  through
# words =  all
# words =  painfully
# words =  in
# words =  execution
#
#  ['does', 'nt', 'quite', 'justice', 'the', 'awfulness', 'the', 'movie', 'that', 'comes', 'through', 'too', 'painfully', 'the', 'execution']
#
# word:  does negative:  6
# word:  the positive:  31
# word:  the positive:  31
# word:  movie positive:  13
# word:  that positive:  1
# word:  through positive:  1
# word:  the positive:  31
# quite
# justice
# awfulness
# too
# painfully
# execution
# words =  a
# words =  unnecessary
# words =  retread
# words =  a
# words =  copy
# words =  of
# words =  picture
# words =  that
# words =  nt
# words =  all
# words =  great
# words =  to
# words =  with
#
#  ['tired', 'unnecessary', 'retread', 'stale', 'copy', 'a', 'picture', 'was', 'nt', 'that', 'great', 'begin']
#
# word:  a positive:  14
# word:  picture positive:  1
# word:  nt positive:  3
# word:  that positive:  2
# word:  great positive:  6
# tired
# unnecessary
# retread
# stale
# copy
# was
# begin
# words =  this
# words =  feel
# words =  to
# words =  as
# words =  the
# words =  is
# words =  trying
# words =  to
# words =  the
# words =  into
# words =  taking
# words =  it
# words =  as
# words =  important
# words =  simply
# words =  because
# words =  the
# words =  is
# words =  ugly
# words =  to
# words =  at
# words =  not
# words =  hollywood
# words =  product
#
#  ['sneaky', 'feel', 'if', 'director', 'is', 'trying', 'dupe', 'viewer', 'into', 'taking', 'it', 'all', 'very', 'important', 'simply', 'because', 'movie', 'is', 'ugly', 'look', 'and', 'a', 'hollywood', 'product']
#
# word:  if negative:  5
# word:  is positive:  24
# word:  trying negative:  1
# word:  into negative:  4
# word:  taking negative:  1
# word:  it positive:  2
# word:  all positive:  3
# word:  simply positive:  1
# word:  movie positive:  14
# word:  is positive:  24
# word:  look positive:  3
# word:  and positive:  1
# word:  a positive:  15
# word:  hollywood positive:  1
# word:  product negative:  4
# sneaky
# feel
# director
# dupe
# viewer
# very
# important
# because
# ugly
# words =  a
# words =  hunk
# words =  of
# words =  garbage
#
#  ['soulless', 'hunk', 'exploitative', 'garbage']
#
# score =  0
# words =  rather
# words =  pity
# words =  anyone
# words =  who
# words =  this
#
#  ['rather', 'pity', 'anyone', 'sees', 'mishmash']
#
# word:  anyone positive:  1
# rather
# pity
# sees
# mishmash
# words =  if
# words =  was
# words =  bored
# words =  and
# words =  to
# words =  a
# words =  pretentious
# words =  version
# words =  of
# words =  son
#
#  ['somebody', 'was', 'bored', 'decided', 'make', 'dull', 'pretentious', 'version', 'jesus', 'son']
#
# word:  was positive:  1
# somebody
# bored
# decided
# pretentious
# version
# jesus
# son
# words =  it
# words =  little
# words =  doubt
# words =  that
# words =  has
# words =  become
# words =  one
# words =  our
# words =  best
# words =  actors
#
#  ['leaves', 'little', 'doubt', 'kidman', 'has', 'become', 'of', 'our', 'best', 'actors']
#
# word:  little negative:  1
# word:  has positive:  6
# word:  best positive:  16
# leaves
# doubt
# kidman
# become
# our
# actors
# words =  a
# words =  of
# words =  elegance
# words =  literary
# words =  lyricism
# words =  and
# words =  common
# words =  sense
#
#  ['work', 'intricate', 'elegance', 'literary', 'lyricism', 'profound', 'common', 'sense']
#
# word:  work positive:  8
# word:  sense positive:  5
# intricate
# elegance
# literary
# lyricism
# profound
# common
# words =  his
# words =  work
#
#  ['best', 'work']
#
# word:  best positive:  17
# word:  work positive:  9
# words =  in
# words =  vat
# words =  of
# words =  jokes
# words =  twitchy
# words =  acting
# words =  and
# words =  boorishness
#
#  ['a', 'vat', 'failed', 'jokes', 'twitchy', 'acting', 'general', 'boorishness']
#
# word:  a positive:  16
# word:  acting positive:  1
# vat
# failed
# jokes
# twitchy
# general
# boorishness
# words =  that
# words =  songbird
# words =  britney
# words =  spears
# words =  has
# words =  popped
# words =  up
# words =  more
# words =  mindless
# words =  drivel
#
#  ['chirpy', 'songbird', 'britney', 'spears', 'has', 'popped', 'with', 'more', 'mindless', 'drivel']
#
# word:  has positive:  7
# word:  more positive:  1
# word:  mindless negative:  1
# chirpy
# songbird
# britney
# spears
# popped
# with
# drivel
# words =  are
# words =  crisp
# words =  and
# words =  without
# words =  overdoing
# words =  it
#
#  ['are', 'crisp', 'purposeful', 'without', 'overdoing']
#
# word:  are positive:  15
# crisp
# purposeful
# without
# overdoing
# words =  is
# words =  dicaprio
# words =  s
# words =  best
# words =  performance
# words =  in
# words =  ever
# words =  and
# words =  the
# words =  watchable
# words =  film
# words =  of
# words =  year
#
#  ['is', 'dicaprio', 's', 'best', 'performance', 'anything', 'ever', 'easily', 'most', 'watchable', 'film', 'the', 'year']
#
# word:  is positive:  26
# word:  s negative:  17
# word:  best positive:  18
# word:  easily positive:  5
# word:  most positive:  16
# word:  film positive:  10
# word:  the positive:  34
# word:  year negative:  3
# dicaprio
# performance
# anything
# watchable
# words =  deep
# words =  down
# words =  i
# words =  realized
# words =  the
# words =  reality
# words =  of
# words =  situation
# words =  i
# words =  would
# words =  the
# words =  with
# words =  lower
# words =  i
# words =  q
# words =  than
# words =  when
# words =  had
# words =  entered
#
#  ['deep', 'down', 'i', 'realized', 'harsh', 'reality', 'my', 'situation', 'i', 'leave', 'theater', 'a', 'lower', 'i', 'q', 'than', 'i', 'had', 'entered']
#
# word:  i negative:  13
# word:  my negative:  4
# word:  i negative:  13
# word:  a positive:  17
# word:  i negative:  13
# word:  than negative:  3
# word:  i negative:  13
# deep
# down
# realized
# harsh
# reality
# situation
# leave
# theater
# lower
# q
# had
# entered
# words =  love
# words =  the
#
#  ['love', 'film']
#
# word:  love positive:  6
# word:  film positive:  11
# words =  jones
# words =  makes
# words =  a
# words =  impression
# words =  as
# words =  writerdirector
# words =  of
# words =  little
# words =  18
# words =  million
# words =  charmer
# words =  which
# words =  not
# words =  cuttingedge
# words =  indie
# words =  filmmaking
# words =  but
# words =  a
# words =  heart
#
#  ['jones', 'makes', 'great', 'impression', 'the', 'writerdirector', 'this', 'little', '18', 'million', 'charmer', 'may', 'be', 'cuttingedge', 'indie', 'filmmaking', 'has', 'huge', 'heart']
#
# word:  makes positive:  1
# word:  great positive:  7
# word:  the positive:  35
# word:  this positive:  2
# word:  be negative:  2
# word:  filmmaking positive:  4
# word:  has positive:  8
# jones
# impression
# writerdirector
# 18
# million
# charmer
# may
# cuttingedge
# indie
# huge
# heart
# words =  nasty
# words =  ugly
# words =  pointless
# words =  and
# words =  even
# words =  if
# words =  hate
# words =  clowns
#
#  ['nasty', 'ugly', 'pointless', 'depressing', 'even', 'you', 'hate', 'clowns']
#
# word:  ugly positive:  1
# word:  pointless negative:  2
# word:  even negative:  1
# word:  you positive:  1
# nasty
# depressing
# hate
# clowns
# words =  succeeds
# words =  as
# words =  wellmade
# words =  evocation
# words =  of
# words =  subculture
#
#  ['succeeds', 'a', 'wellmade', 'evocation', 'a', 'subculture']
#
# word:  a positive:  17
# word:  wellmade positive:  1
# word:  a positive:  17
# succeeds
# evocation
# subculture
# words =  stinks
# words =  from
# words =  to
# words =  like
# words =  wet
# words =  burlap
# words =  sack
# words =  of
#
#  ['stinks', 'start', 'finish', 'a', 'wet', 'burlap', 'sack', 'gloom']
#
# word:  a positive:  19
# stinks
# start
# finish
# wet
# burlap
# sack
# gloom
# words =  send
# words =  it
# words =  cranky
# words =  we
# words =  nt
# words =  get
# words =  enough
# words =  to
# words =  through
# words =  crap
# words =  like
#
#  ['send', 'cranky', 'do', 'nt', 'paid', 'enough', 'to', 'sit', 'through', 'crap', 'this']
#
# word:  nt positive:  4
# word:  enough negative:  6
# word:  to positive:  2
# word:  through positive:  2
# word:  this positive:  3
# send
# cranky
# do
# paid
# sit
# crap
# words =  delightfully
# words =  rendered
#
#  ['delightfully', 'rendered']
#
# word:  delightfully negative:  1
# rendered
# words =  a
# words =  manipulative
# words =  stinker
# words =  the
# words =  passes
# words =  time
# words =  it
# words =  time
# words =  an
# words =  finale
# words =  of
# words =  metal
#
#  ['predictable', 'manipulative', 'stinker', 'story', 'passes', 'until', 's', 'for', 'absurd', 'finale', 'twisted', 'metal']
#
# word:  story positive:  6
# word:  s negative:  17
# predictable
# manipulative
# stinker
# passes
# until
# for
# absurd
# finale
# twisted
# metal
# words =  wonderfully
# words =  speculative
#
#  ['wonderfully', 'speculative']
#
# score =  0
# words =  a
# words =  high
# words =  school
# words =  production
#
#  ['bad', 'high', 'school', 'production']
#
# word:  bad negative:  16
# high
# school
# production
# words =  an
# words =  awful
# words =  study
# words =  in
# words =  and
#
#  ['unclassifiably', 'awful', 'study', 'self', 'audienceabuse']
#
# score =  0
# words =  the
# words =  adam
# words =  sandler
# words =  assault
# words =  and
# words =  the
# words =  film
# words =  of
# words =  year
#
#  ['latest', 'adam', 'sandler', 'assault', 'possibly', 'worst', 'film', 'the', 'year']
#
# word:  possibly negative:  1
# word:  worst negative:  8
# word:  film positive:  12
# word:  the positive:  36
# latest
# adam
# sandler
# assault
# words =  we
# words =  forced
# words =  to
# words =  that
# words =  visual
# words =  imagination
# words =  is
# words =  breathtaking
#
#  ['are', 'forced', 'reflect', 'its', 'visual', 'imagination', 'is', 'breathtaking']
#
# word:  are positive:  16
# word:  its negative:  3
# word:  is positive:  27
# word:  breathtaking positive:  1
# forced
# reflect
# visual
# imagination
# words =  is
# words =  pure
# words =  exciting
# words =  moviemaking
#
#  ['is', 'pure', 'exciting', 'moviemaking']
#
# word:  is positive:  28
# word:  pure positive:  1
# exciting
# moviemaking
# words =  you
# words =  gonna
# words =  like
# words =  movie
#
#  ['re', 'gonna', 'this', 'movie']
#
# word:  re negative:  1
# word:  this positive:  4
# word:  movie positive:  15
# gonna
# words =  a
# words =  piece
# words =  of
# words =  poetry
# words =  that
# words =  hopefully
# words =  be
# words =  as
# words =  of
# words =  most
# words =  important
# words =  stories
# words =  to
# words =  told
# words =  in
# words =  s
# words =  film
# words =  history
#
#  ['stunning', 'piece', 'visual', 'poetry', 'will', 'hopefully', 'remembered', 'one', 'the', 'most', 'important', 'stories', 'be', 'told', 'australia', 's', 'film', 'history']
#
# word:  piece positive:  1
# word:  visual positive:  1
# word:  will positive:  3
# word:  the positive:  37
# word:  most positive:  17
# word:  important positive:  1
# ...
# words =  few
# words =  films
# words =  capture
# words =  so
# words =  the
# words =  and
# words =  of
# words =  boys
# words =  on
# words =  fields
# words =  as
# words =  as
# words =  grown
# words =  men
# words =  who
# words =  in
# words =  stands
#
#  ['few', 'films', 'capture', 'perfectly', 'hopes', 'dreams', 'little', 'boys', 'baseball', 'fields', 'well', 'the', 'grown', 'men', 'sit', 'the', 'stands']
#
# word:  films positive:  10
# word:  little positive:  2
# word:  well positive:  2
# word:  the positive:  40
# word:  sit positive:  1
# word:  the positive:  40
# few
# capture
# perfectly
# hopes
# dreams
# boys
# baseball
# fields
# grown
# men
# stands
# words =  is
# words =  one
# words =  the
# words =  examples
# words =  of
# words =  large
# words =  format
# words =  filmmaking
# words =  you
# words =  likely
# words =  to
# words =  anytime
# words =  soon
#
#  ['is', 'best', 'examples', 'of', 'artful', 'large', 'format', 'filmmaking', 'are', 'likely', 'see', 'anytime', 'soon']
#
# word:  is positive:  32
# word:  best positive:  19
# word:  of positive:  3
# word:  large positive:  1
# word:  filmmaking positive:  5
# word:  are positive:  17
# word:  likely negative:  1
# word:  see positive:  2
# examples
# artful
# format
# anytime
# soon
# words =  with
# words =  candylike
# words =  taste
# words =  of
# words =  fading
# words =  faster
# words =  than
# words =  25cent
# words =  bubble
# words =  gum
# words =  i
# words =  realized
# words =  this
# words =  a
# words =  movie
# words =  that
# words =  nt
# words =  stand
# words =  the
# words =  of
# words =  it
# words =  a
#
#  ['candylike', 'taste', 'fading', 'faster', 'than', '25cent', 'bubble', 'gum', 'i', 'realized', 'is', 'throwaway', 'movie', 'wo', 'nt', 'stand', 'the', 'test', 'time', 'it', 's', 'trifle']
#
# word:  than negative:  4
# word:  i negative:  17
# word:  realized negative:  1
# word:  is positive:  33
# word:  movie positive:  17
# word:  nt positive:  6
# word:  the positive:  42
# word:  time negative:  4
# word:  it positive:  4
# word:  s negative:  20
# candylike
# taste
# fading
# faster
# 25cent
# bubble
# gum
# throwaway
# wo
# stand
# test
# trifle
# words =  a
# words =  rewarding
# words =  experience
# words =  that
# words =  every
# words =  bit
# words =  as
# words =  insightful
# words =  and
# words =  as
# words =  s
# words =  two
# words =  best
# words =  films
#
#  ['hugely', 'rewarding', 'experience', 's', 'every', 'bit', 'enlightening', 'insightful', 'entertaining', 'grant', 's', 'two', 'best', 'films']
#
# word:  hugely positive:  1
# word:  experience positive:  1
# word:  s negative:  20
# word:  every positive:  2
# word:  grant positive:  1
# word:  s negative:  20
# word:  two positive:  1
# word:  best positive:  20
# word:  films positive:  11
# rewarding
# bit
# enlightening
# insightful
# entertaining
# words =  innocent
# words =  childlike
# words =  and
# words =  funny
#
#  ['innocent', 'childlike', 'inherently', 'funny']
#
# score =  0
# words =  the
# words =  thing
# words =  scary
# words =  about
# words =  is
# words =  that
# words =  filmmakers
# words =  and
# words =  are
# words =  brazen
# words =  enough
# words =  to
# words =  to
# words =  this
# words =  off
# words =  as
# words =  scary
# words =  movie
#
#  ['only', 'thing', 'scary', 'feardotcom', 'is', 'the', 'filmmakers', 'studio', 'are', 'brazen', 'enough', 'attempt', 'pass', 'stinker', 'off', 'a', 'scary', 'movie']
#
# word:  is positive:  34
# word:  the positive:  43
# word:  are positive:  18
# word:  enough negative:  6
# word:  stinker negative:  1
# word:  off positive:  2
# word:  a positive:  22
# word:  movie positive:  18
# only
# thing
# scary
# feardotcom
# filmmakers
# studio
# brazen
# attempt
# pass
# words =  ll
# words =  certainly
# words =  be
# words =  an
# words =  out
# words =  his
# words =  project
#
#  ['ll', 'certainly', 'keeping', 'eye', 'for', 'next', 'project']
#
# word:  ll positive:  2
# word:  for negative:  1
# certainly
# keeping
# eye
# next
# project
# words =  flatout
# words =  amusing
# words =  sometimes
# words =  endearing
# words =  and
# words =  fabulous
#
#  ['flatout', 'amusing', 'sometimes', 'endearing', 'often', 'fabulous']
#
# word:  amusing positive:  1
# word:  often positive:  5
# flatout
# sometimes
# endearing
# fabulous
# words =  an
# words =  swedish
# words =  film
# words =  about
# words =  soul
# words =  adventure
# words =  of
# words =  the
# words =  of
# words =  and
# words =  film
# words =  that
# words =  august
# words =  does
# words =  best
#
#  ['extraordinary', 'swedish', 'film', 'soul', 'adventure', 'marriage', 'the', 'kind', 'intimate', 'characterdriven', 'film', 'bille', 'august', 'does', 'best']
#
# word:  film positive:  14
# word:  adventure positive:  2
# word:  the positive:  44
# word:  film positive:  14
# word:  does negative:  6
# word:  best positive:  20
# extraordinary
# swedish
# soul
# marriage
# kind
# intimate
# characterdriven
# bille
# august
# words =  might
# words =  even
# words =  praise
# words =  god
# words =  for
# words =  such
# words =  an
# words =  camp
# words =  classic
#
#  ['might', 'even', 'praise', 'god', 'delivering', 'such', 'instant', 'camp', 'classic']
#
# word:  might negative:  1
# word:  praise positive:  1
# word:  delivering positive:  1
# word:  such positive:  2
# god
# instant
# camp
# classic
# words =  andrew
# words =  s
# words =  turnabout
# words =  is
# words =  fair
# words =  play
# words =  is
# words =  every
# words =  bit
# words =  as
# words =  as
# words =  s
# words =  coven
#
#  ['andrew', 's', 'turnabout', 'is', 'fair', 'play', 'is', 'every', 'bit', 'awful', 'borchardt', 's', 'coven']
#
# word:  s negative:  22
# word:  is positive:  35
# word:  is positive:  35
# word:  every positive:  2
# word:  bit negative:  1
# word:  s negative:  22
# andrew
# turnabout
# fair
# play
# awful
# borchardt
# coven
# words =  collapses
# words =  like
# words =  overcooked
# words =  soufflأ©
#
#  ['collapses', 'an', 'overcooked', 'soufflأ©']
#
# word:  an positive:  5
# collapses
# overcooked
# soufflأ©
# words =  whiny
# words =  pathetic
# words =  starving
# words =  and
# words =  artistes
#
#  ['whiny', 'pathetic', 'starving', 'untalented', 'artistes']
#
# score =  0
# words =  is
# words =  rather
# words =  like
# words =  trapped
# words =  while
# words =  some
# words =  weird
# words =  relative
# words =  trots
# words =  out
# words =  video
# words =  he
# words =  of
# words =  family
# words =  vacation
# words =  to
# words =  before
# words =  long
# words =  you
# words =  desperate
# words =  for
# words =  evening
# words =  to
#
#  ['is', 'rather', 'being', 'trapped', 'while', 'some', 'weird', 'relative', 'trots', 'the', 'video', 'took', 'the', 'family', 'vacation', 'stonehenge', 'before', 'long', 're', 'desperate', 'the', 'evening', 'end']
#
# word:  is positive:  37
# word:  rather positive:  1
# word:  being positive:  1
# word:  some negative:  4
# word:  the positive:  45
# word:  the positive:  45
# word:  family positive:  1
# word:  long negative:  1
# word:  the positive:  45
# word:  end positive:  1
# trapped
# while
# weird
# relative
# trots
# video
# took
# vacation
# stonehenge
# before
# desperate
# evening
# words =  a
# words =  selfparody
# words =  that
# words =  like
# words =  weird
# words =  masterpiece
# words =  theater
# words =  sketch
# words =  with
# words =  a
# words =  of
# words =  nor
# words =  a
# words =  reason
#
#  ['mawkish', 'selfparody', 'plays', 'some', 'weird', 'masterpiece', 'theater', 'sketch', 'neither', 'point', 'view', 'nor', 'compelling', 'reason']
#
# word:  some negative:  4
# word:  weird positive:  1
# word:  masterpiece positive:  5
# word:  theater negative:  1
# word:  view positive:  1
# mawkish
# selfparody
# plays
# sketch
# neither
# point
# nor
# compelling
# reason
# words =  bad
# words =  mannered
# words =  ugly
# words =  and
# words =  little
#
#  ['bad', 'mannered', 'ugly', 'destructive', 'little']
#
# word:  bad negative:  19
# word:  little positive:  3
# mannered
# destructive
# words =  been
# words =  allowed
# words =  to
# words =  the
# words =  new
# words =  in
# words =  title
# words =  because
# words =  there
# words =  not
# words =  original
# words =  character
# words =  siuation
# words =  or
# words =  in
# words =  entire
# words =  movie
#
#  ['been', 'allowed', 'use', 'word', 'new', 'its', 'title', 'because', 's', 'an', 'original', 'character', 'siuation', 'joke', 'the', 'entire', 'movie']
#
# word:  new negative:  1
# word:  because positive:  1
# word:  s negative:  22
# word:  an positive:  6
# word:  original positive:  1
# word:  character positive:  1
# word:  joke positive:  1
# word:  the positive:  48
# word:  movie positive:  19
# been
# allowed
# use
# word
# title
# siuation
# entire
# words =  bloody
# words =  sunday
# words =  has
# words =  the
# words =  to
# words =  for
# words =  rather
# words =  than
# words =  to
# words =  blame
# words =  making
# words =  it
# words =  of
# words =  best
# words =  war
# words =  movies
# words =  ever
# words =  made
#
#  ['bloody', 'sunday', 'has', 'grace', 'call', 'prevention', 'rather', 'than', 'place', 'blame', 'making', 'one', 'the', 'best', 'war', 'movies', 'ever', 'made']
#
# word:  has positive:  11
# word:  rather positive:  2
# word:  than negative:  4
# word:  making positive:  1
# word:  one positive:  2
# word:  the positive:  49
# word:  best positive:  21
# word:  ever positive:  2
# bloody
# sunday
# grace
# call
# prevention
# place
# blame
# war
# movies
# made
# words =  pity
# words =  anyone
# words =  who
# words =  this
#
#  ['pity', 'anyone', 'sees', 'mishmash']
#
# word:  pity positive:  1
# word:  anyone positive:  2
# word:  sees positive:  1
# word:  mishmash positive:  1
# words =  deserves
# words =  to
# words =  seen
# words =  by
# words =  with
# words =  a
# words =  interest
# words =  in
# words =  events
# words =  shaping
# words =  the
# words =  beyond
# words =  their
# words =  horizons
#
#  ['deserves', 'be', 'seen', 'anyone', 'even', 'passing', 'interest', 'events', 'shaping', 'the', 'world', 'beyond', 'own', 'horizons']
#
# word:  deserves positive:  5
# word:  seen positive:  1
# word:  anyone positive:  3
# word:  even positive:  3
# word:  the positive:  50
# word:  own positive:  1
# passing
# interest
# events
# shaping
# world
# beyond
# horizons
# words =  the
# words =  of
# words =  during
# words =  which
# words =  want
# words =  to
# words =  your
# words =  head
# words =  on
# words =  seat
# words =  in
# words =  of
# words =  at
# words =  cluelessness
# words =  at
# words =  idiocy
# words =  at
# words =  utterly
# words =  misplaced
# words =  earnestness
#
#  ['kind', 'movie', 'during', 'you', 'want', 'bang', 'your', 'head', 'the', 'seat', 'front', 'you', 'its', 'cluelessness', 'its', 'idiocy', 'its', 'utterly', 'misplaced', 'earnestness']
#
# word:  kind positive:  1
# word:  movie positive:  20
# word:  want negative:  5
# word:  your positive:  1
# word:  the positive:  51
# word:  its positive:  4
# word:  its positive:  4
# word:  its positive:  4
# word:  utterly positive:  1
# during
# bang
# head
# seat
# front
# cluelessness
# idiocy
# misplaced
# earnestness
# words =  is
# words =  great
# words =  in
# words =  role
#
#  ['is', 'great', 'his', 'role']
#
# word:  is positive:  38
# word:  great positive:  8
# word:  his positive:  9
# role
# words =  the
# words =  film
# words =  comedies
# words =  in
#
#  ['worst', 'film', 'comedies', 'decades']
#
# word:  worst negative:  9
# word:  film positive:  16
# word:  comedies positive:  2
# decades
# words =  a
# words =  waste
# words =  of
#
#  ['complete', 'waste', 'time']
#
# word:  time negative:  4
# complete
# waste
# words =  first
# words =  real
# words =  masterpiece
#
#  ['first', 'real', 'masterpiece']
#
# word:  first positive:  7
# word:  masterpiece positive:  6
# real
# words =  this
# words =  a
# words =  film
# words =  because
# words =  there
# words =  no
# words =  hero
# words =  and
# words =  allout
# words =  villain
#
#  ['is', 'fascinating', 'film', 'because', 'is', 'clearcut', 'hero', 'no', 'allout', 'villain']
#
# word:  is positive:  39
# word:  fascinating positive:  1
# word:  film positive:  17
# word:  because positive:  2
# word:  is positive:  39
# word:  no positive:  2
# clearcut
# hero
# allout
# villain
# words =  that
# words =  ever
# words =  walked
# words =  the
# words =  tightrope
# words =  between
# words =  farcical
# words =  and
# words =  in
# words =  wrong
# words =  hands
# words =  i
# words =  e
# words =  peploe
# words =  s
# words =  it
# words =  simply
# words =  unbearable
#
#  ['only', 'ever', 'walked', 'delicate', 'tightrope', 'between', 'farcical', 'loathsome', 'the', 'wrong', 'hands', 'i', 'e', 'peploe', 's', 's', 'simply', 'unbearable']
#
# word:  only positive:  1
# word:  ever positive:  3
# word:  walked negative:  1
# word:  between positive:  2
# word:  the positive:  52
# word:  wrong positive:  1
# word:  i negative:  17
# word:  s negative:  22
# word:  s negative:  22
# word:  simply positive:  2
# delicate
# tightrope
# farcical
# loathsome
# hands
# e
# peploe
# unbearable
# words =  this
# words =  vehicle
# words =  is
# words =  downright
# words =  doltish
# words =  and
#
#  ['vapid', 'vehicle', 'is', 'downright', 'doltish', 'uneventful']
#
# word:  is positive:  41
# word:  downright negative:  1
# vapid
# vehicle
# doltish
# uneventful
# words =  a
# words =  that
# words =  barely
# words =  shocking
# words =  barely
# words =  interesting
# words =  and
# words =  of
# words =  barely
# words =  anything
#
#  ['film', 's', 'barely', 'shocking', 'barely', 'interesting', 'most', 'all', 'barely', 'anything']
#
# word:  film positive:  18
# word:  s negative:  24
# word:  most positive:  18
# word:  all positive:  4
# word:  anything positive:  1
# barely
# shocking
# interesting
# words =  infantile
# words =  that
# words =  you
# words =  about
# words =  the
# words =  and
# words =  s
# words =  diapers
#
#  ['infantile', 'makes', 'wonder', 'changing', 'director', 'writer', 's', 'diapers']
#
# word:  makes positive:  2
# word:  changing positive:  1
# word:  director positive:  1
# word:  s negative:  24
# infantile
# wonder
# writer
# diapers
# words =  leave
# words =  the
# words =  with
# words =  lower
# words =  i
# words =  q
# words =  than
# words =  when
# words =  had
# words =  entered
#
#  ['leave', 'theater', 'a', 'lower', 'i', 'q', 'than', 'i', 'had', 'entered']
#
# word:  leave negative:  1
# word:  a positive:  23
# word:  lower negative:  1
# word:  i negative:  18
# word:  q negative:  1
# word:  than negative:  4
# word:  i negative:  18
# word:  had negative:  1
# word:  entered negative:  1
# words =  emerges
# words =  as
# words =  very
# words =  best
# words =  of
#
#  ['emerges', 'the', 'very', 'best', 'them']
#
# word:  the positive:  52
# word:  very positive:  1
# word:  best positive:  22
# word:  them positive:  2
# emerges
# words =  a
# words =  a
# words =  that
# words =  out
# words =  world
# words =  and
# words =  us
# words =  effortlessly
# words =  from
# words =  to
#
#  ['triumph', 'film', 'hews', 'a', 'world', 'carries', 'us', 'effortlessly', 'darkness', 'light']
#
# word:  triumph positive:  1
# word:  film positive:  19
# word:  a positive:  23
# word:  world positive:  1
# word:  us negative:  1
# hews
# carries
# effortlessly
# darkness
# light
# words =  looks
# words =  like
# words =  action
# words =  movie
# words =  but
# words =  s
# words =  so
# words =  made
# words =  on
# words =  levels
# words =  that
# words =  does
# words =  nt
# words =  even
# words =  qualify
# words =  as
# words =  spoof
# words =  of
#
#  ['looks', 'an', 'action', 'movie', 'it', 's', 'poorly', 'made', 'all', 'levels', 'it', 'does', 'nt', 'even', 'qualify', 'a', 'spoof', 'such']
#
# word:  an positive:  7
# word:  action negative:  1
# word:  movie positive:  21
# word:  it positive:  5
# word:  s negative:  25
# word:  made positive:  1
# word:  all positive:  5
# word:  it positive:  5
# word:  does negative:  6
# word:  nt positive:  7
# word:  even positive:  4
# word:  a positive:  24
# word:  such positive:  3
# looks
# poorly
# levels
# qualify
# spoof
# words =  dazzling
# words =  in
# words =  complexity
#
#  ['dazzling', 'its', 'complexity']
#
# word:  its positive:  7
# dazzling
# complexity
# words =  s
# words =  a
# words =  groove
# words =  that
# words =  you
# words =  more
#
#  ['s', 'glorious', 'groove', 'leaves', 'wanting', 'more']
#
# word:  s negative:  25
# word:  leaves positive:  1
# word:  more positive:  2
# glorious
# groove
# wanting
# words =  a
# words =  entertaining
# words =  specimen
# words =  of
# words =  scifi
#
#  ['terrifically', 'entertaining', 'specimen', 'spielbergian', 'scifi']
#
# word:  terrifically positive:  1
# word:  entertaining negative:  1
# score =  0
# words =  not
# words =  unlikable
# words =  disturbing
# words =  disgusting
# words =  without
# words =  any
# words =  redeeming
# words =  value
# words =  whatsoever
#
#  ['just', 'unlikable', 'disturbing', 'disgusting', 'without', 'any', 'redeeming', 'value', 'whatsoever']
#
# word:  just negative:  4
# word:  without positive:  1
# word:  any negative:  7
# unlikable
# disturbing
# disgusting
# redeeming
# value
# whatsoever
# Your method has a training accuracy of 56.49999999999999%

# %%
words = ['the','be','to','of','and','a','in','that','have','I','it','for','not','on','with','he','as','you','do','at','this','but','his','by','from','they','we','say','her','she','or','an','will','my','one','all','would','there','their','what','so','up','out','if','about','who','get','which','go','me','when','make','can','like','time','no','just','him']
stat = 'to he be continue'


res = stat.split()
print(res)
for x in res:
    if x in words:
        res.remove(x)

print(res)
# Out:
# ['to', 'he', 'be', 'continue']
# ['he', 'continue']

# %% [markdown]
# ## 5. Evaluate (10/100 points)
# You may already notice that there is an extra evaluation function in the above coding block which helps calculate the accuracy for your algorithm on the training dataset. The metric that we used to evaluate is straightforward:
# $$\text{accuracy} = \frac{\text{# of correct prediction}}{\text{# of total cases}}$$
# Now, let's test the performance of your algorithm on the test dataset (as if deployed on new reviews)!
#
# Try to get the **test accuracy** to be higher than 55% to receive **full credit**!
#
# Note: You should not have the accuracy to be lower than 50%! (Why?)

# %%
import sys
sys.path.append(dir_root)
from top_classified_file import super_secret_function

test_dir = os.path.join(dir_root, 'test.npy')
test_acc = super_secret_function(test_dir, sentiment_analysis)

print(f"Your method has a test accuracy of {test_acc*100}%")
# Out:
# words =  the
# words =  films
# words =  of
#
#  ['worst', 'films', '2002']
#
# word:  worst negative:  9
# word:  films positive:  11
# word:  2002 positive:  1
# words =  have
# words =  frida
# words =  with
# words =  visual
# words =  style
# words =  unique
# words =  and
# words =  to
# words =  titular
# words =  character
# words =  s
# words =  paintings
# words =  and
# words =  the
# words =  created
# words =  a
# words =  work
# words =  of
# words =  of
# words =  own
#
#  ['infused', 'frida', 'visual', 'style', 'unique', 'inherent', 'titular', 'character', 's', 'paintings', 'in', 'the', 'process', 'created', 'a', 'masterful', 'work', 'art', 'their', 'own']
#
# word:  visual positive:  2
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# word:  character positive:  2
# word:  s negative:  26
# word:  in positive:  1
# word:  the positive:  53
# word:  process positive:  1
# word:  a positive:  25
# word:  work positive:  10
# word:  their positive:  5
# word:  own positive:  2
# infused
# frida
# style
# unique
# inherent
# titular
# paintings
# created
# masterful
# art
# words =  what
# words =  idea
# words =  what
# words =  thrill
# words =  ride
# words =  this
# words =  a
# words =  fascinating
# words =  look
# words =  at
# words =  future
# words =  than
# words =  bladerunner
# words =  and
# words =  of
# words =  most
# words =  highconcept
# words =  sci
# words =  fi
# words =  adventures
# words =  attempted
# words =  for
# words =  screen
#
#  ['an', 'idea', 'thrill', 'ride', 'is', 'a', 'more', 'fascinating', 'look', 'the', 'future', 'than', 'bladerunner', 'one', 'the', 'most', 'highconcept', 'sci', 'fi', 'adventures', 'attempted', 'the', 'screen']
#
# word:  an positive:  8
# word:  idea negative:  1
# word:  is positive:  42
# word:  a positive:  26
# word:  more positive:  2
# word:  fascinating positive:  2
# word:  look positive:  4
# word:  the positive:  54
# word:  than negative:  5
# word:  one positive:  3
# word:  the positive:  54
# word:  most positive:  19
# word:  the positive:  54
# thrill
# ride
# future
# bladerunner
# highconcept
# sci
# fi
# adventures
# attempted
# screen
# words =  is
# words =  a
# words =  of
# words =  wit
# words =  and
#
#  ['is', 'masterpiece', 'elegant', 'wit', 'artifice']
#
# word:  is positive:  43
# word:  masterpiece positive:  7
# word:  artifice positive:  1
# elegant
# wit
# words =  is
# words =  a
# words =  piece
# words =  of
#
#  ['is', 'remarkable', 'piece', 'filmmaking']
#
# word:  is positive:  44
# word:  piece positive:  2
# word:  filmmaking positive:  6
# words =  are
# words =  incredibly
# words =  captivating
# words =  and
# words =  funny
#
#  ['are', 'incredibly', 'captivating', 'insanely', 'funny']
#
# word:  are positive:  19
# captivating
# insanely
# words =  even
# words =  elizabeth
# words =  hurley
# words =  seem
# words =  graceless
# words =  and
#
#  ['even', 'elizabeth', 'hurley', 'seem', 'graceless', 'ugly']
#
# word:  even positive:  5
# word:  graceless negative:  1
# word:  ugly negative:  2
# elizabeth
# hurley
# words =  haneke
# words =  s
# words =  script
# words =  from
# words =  jelinek
# words =  s
# words =  novel
# words =  is
# words =  contrived
# words =  unmotivated
# words =  and
# words =  unpersuasive
# words =  with
# words =  inconclusive
# words =  ending
#
#  ['haneke', 's', 'script', 'elfriede', 'jelinek', 's', 'novel', 'is', 'contrived', 'unmotivated', 'psychologically', 'unpersuasive', 'an', 'inconclusive', 'ending']
#
# word:  s negative:  26
# word:  script negative:  1
# word:  s negative:  26
# word:  novel positive:  1
# word:  is positive:  45
# word:  an positive:  9
# haneke
# elfriede
# jelinek
# contrived
# unmotivated
# psychologically
# unpersuasive
# inconclusive
# ending
# words =  it
# words =  definitely
# words =  not
# words =  for
# words =  or
# words =  parents
# words =  for
# words =  matter
# words =  and
# words =  think
# words =  even
# words =  fans
# words =  of
# words =  s
# words =  comic
# words =  taste
# words =  may
# words =  find
# words =  it
#
#  ['s', 'definitely', 'made', 'kids', 'their', 'parents', 'that', 'matter', 'i', 'think', 'even', 'fans', 'sandler', 's', 'comic', 'taste', 'may', 'find', 'uninteresting']
#
# word:  s negative:  26
# word:  made positive:  2
# word:  their positive:  6
# word:  that positive:  3
# word:  i negative:  20
# word:  think negative:  1
# word:  even positive:  6
# word:  sandler positive:  1
# word:  s negative:  26
# word:  taste positive:  1
# word:  may positive:  1
# definitely
# kids
# parents
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# matter
# fans
# comic
# find
# uninteresting
# words =  s
# words =  almost
# words =  impossible
# words =  not
# words =  be
# words =  away
# words =  by
# words =  sheer
# words =  beauty
# words =  of
# words =  images
#
#  ['s', 'almost', 'impossible', 'to', 'swept', 'away', 'the', 'sheer', 'beauty', 'his', 'images']
#
# word:  s negative:  28
# word:  almost positive:  2
# word:  to positive:  3
# word:  the positive:  57
# word:  his positive:  10
# impossible
# swept
# away
# sheer
# beauty
# images
# words =  putrid
# words =  it
# words =  not
# words =  the
# words =  of
# words =  match
# words =  that
# words =  be
# words =  to
# words =  every
# words =  print
# words =  of
# words =  film
#
#  ['putrid', 'is', 'worth', 'price', 'the', 'match', 'should', 'used', 'burn', 'every', 'print', 'the', 'film']
#
# word:  is positive:  46
# word:  worth positive:  1
# word:  the positive:  58
# word:  should positive:  1
# word:  every positive:  3
# word:  the positive:  58
# word:  film positive:  20
# putrid
# price
# match
# used
# burn
# print
# words =  and
# words =  delightful
#
#  ['thoroughly', 'delightful']
#
# word:  thoroughly negative:  1
# delightful
# words =  an
# words =  awful
# words =  study
# words =  in
# words =  and
#
#  ['unclassifiably', 'awful', 'study', 'self', 'audienceabuse']
#
# word:  awful positive:  1
# unclassifiably
# study
# self
# audienceabuse
# words =  an
# words =  comedy
# words =  of
# words =  and
# words =  differences
# words =  the
# words =  is
# words =  a
# words =  full
# words =  of
# words =  and
# words =  delights
# words =  that
# words =  all
# words =  wiggling
# words =  energy
# words =  of
# words =  kitten
#
#  ['enjoyable', 'comedy', 'lingual', 'cultural', 'differences', 'château', 'is', 'film', 'full', 'life', 'small', 'delights', 'has', 'the', 'wiggling', 'energy', 'young', 'kitten']
#
# word:  enjoyable positive:  2
# word:  comedy negative:  7
# word:  is positive:  47
# word:  film positive:  21
# word:  life positive:  1
# word:  has positive:  12
# word:  the positive:  60
# lingual
# cultural
# differences
# château
# full
# small
# delights
# wiggling
# energy
# young
# kitten
# words =  philosophically
# words =  intellectually
# words =  and
# words =  a
#
#  ['philosophically', 'intellectually', 'logistically', 'mess']
#
# score =  0
# words =  but
# words =  miracle
# words =  of
# words =  s
# words =  film
# words =  is
# words =  that
# words =  truly
# words =  is
# words =  romance
#
#  ['the', 'miracle', 'shainberg', 's', 'film', 'is', 'it', 'truly', 'is', 'romance']
#
# word:  the positive:  61
# word:  s negative:  28
# word:  film positive:  22
# word:  is positive:  48
# word:  it positive:  7
# word:  is positive:  48
# miracle
# shainberg
# truly
# romance
# words =  the
# words =  s
# words =  most
# words =  thoughtprovoking
# words =  film
#
#  ['year', 's', 'most', 'thoughtprovoking', 'film']
#
# word:  year positive:  4
# word:  s negative:  28
# word:  most positive:  20
# word:  film positive:  23
# thoughtprovoking
# words =  s
# words =  extreme
# words =  all
# words =  extremely
# words =  dumb
# words =  extremely
# words =  confusing
# words =  extremely
# words =  boring
#
#  ['s', 'extreme', 'right', 'extremely', 'dumb', 'extremely', 'confusing', 'extremely', 'boring']
#
# word:  s negative:  28
# word:  dumb positive:  2
# extreme
# right
# extremely
# confusing
# boring
# words =  poorly
# words =  thoughtout
# words =  and
#
#  ['poorly', 'thoughtout', 'substancefree']
#
# word:  poorly positive:  1
# thoughtout
# substancefree
# words =  bad
# words =  bad
# words =  movie
#
#  ['bad', 'bad', 'movie']
#
# word:  bad negative:  20
# word:  bad negative:  20
# word:  movie positive:  22
# words =  the
# words =  is
# words =  typical
# words =  miike
# words =  fast
# words =  furious
# words =  and
# words =  of
# words =  imaginative
# words =  flourishes
#
#  ['film', 'is', 'typical', 'miike', 'fast', 'furious', 'full', 'offthecuff', 'imaginative', 'flourishes']
#
# word:  film positive:  24
# word:  is positive:  50
# word:  fast negative:  1
# word:  full positive:  1
# typical
# miike
# furious
# offthecuff
# imaginative
# flourishes
# words =  an
# words =  delight
# words =  for
# words =  audiences
#
#  ['absolute', 'delight', 'all', 'audiences']
#
# word:  all positive:  6
# absolute
# delight
# audiences
# words =  a
# words =  sequel
# words =  and
# words =  of
# words =  best
# words =  films
# words =  of
# words =  year
#
#  ['powerful', 'sequel', 'one', 'the', 'best', 'films', 'the', 'year']
#
# word:  one positive:  4
# word:  the positive:  62
# word:  best positive:  23
# word:  films positive:  12
# word:  the positive:  62
# word:  year positive:  5
# powerful
# sequel
# words =  i
# words =  laughed
# words =  throughout
# words =  the
#
#  ['i', 'laughed', 'throughout', 'movie']
#
# word:  i negative:  21
# word:  throughout positive:  2
# word:  movie positive:  22
# laughed
# words =  one
# words =  those
# words =  reputedly
# words =  unfilmable
# words =  novels
# words =  that
# words =  bucked
# words =  the
# words =  to
# words =  as
# words =  exquisite
# words =  motion
# words =  picture
# words =  in
# words =  own
# words =  right
#
#  ['of', 'those', 'reputedly', 'unfilmable', 'novels', 'has', 'bucked', 'odds', 'emerge', 'an', 'exquisite', 'motion', 'picture', 'its', 'own', 'right']
#
# word:  of positive:  4
# word:  those negative:  1
# word:  has positive:  13
# word:  an positive:  10
# word:  exquisite positive:  1
# word:  picture positive:  2
# word:  its positive:  8
# word:  own positive:  3
# word:  right negative:  1
# reputedly
# unfilmable
# novels
# bucked
# odds
# emerge
# motion
# words =  you
# words =  have
# words =  love
# words =  the
# words =  dumb
# words =  happy
# words =  movie
# words =  my
# words =  fat
# words =  greek
# words =  wedding
#
#  ['just', 'to', 'love', 'big', 'dumb', 'happy', 'movie', 'big', 'fat', 'greek', 'wedding']
#
# word:  just negative:  5
# word:  to positive:  4
# word:  love positive:  8
# word:  dumb positive:  2
# word:  happy positive:  1
# word:  movie positive:  23
# big
# fat
# greek
# wedding
# words =  ll
# words =  only
# words =  put
# words =  you
# words =  sleep
#
#  ['ll', 'only', 'put', 'to', 'sleep']
#
# word:  ll positive:  3
# word:  to positive:  5
# put
# sleep
# words =  if
# words =  re
# words =  not
# words =  touched
# words =  by
# words =  movie
# words =  check
# words =  your
# words =  pulse
#
#  ['you', 're', 'deeply', 'touched', 'this', 'movie', 'check', 'your', 'pulse']
#
# word:  you positive:  3
# word:  re positive:  2
# word:  this positive:  5
# word:  movie positive:  24
# word:  your positive:  2
# word:  pulse positive:  1
# deeply
# touched
# check
# words =  the
# words =  top
#
#  ['absolute', 'top']
#
# word:  absolute positive:  1
# word:  top positive:  1
# words =  a
# words =  of
# words =  direction
# words =  over
# words =  narrative
# words =  but
# words =  art
# words =  direction
#
#  ['triumph', 'art', 'direction', 'over', 'narrative', 'what', 'art', 'direction']
#
# word:  triumph positive:  2
# word:  art positive:  1
# word:  direction positive:  1
# word:  what positive:  5
# word:  art positive:  1
# word:  direction positive:  1
# over
# narrative
# words =  hugely
# words =  rewarding
# words =  experience
#
#  ['hugely', 'rewarding', 'experience']
#
# word:  rewarding negative:  1
# words =  too
# words =  boring
# words =  and
#
#  ['too', 'boring', 'obvious']
#
# word:  too positive:  1
# word:  boring negative:  1
# word:  obvious positive:  2
# words =  the
# words =  are
# words =  fantastic
#
#  ['actors', 'are', 'fantastic']
#
# word:  actors positive:  1
# word:  are positive:  20
# word:  fantastic positive:  1
# words =  is
# words =  powerful
# words =  and
#
#  ['is', 'powerful', 'revelatory']
#
# word:  is positive:  51
# word:  powerful positive:  1
# revelatory
# words =  as
# words =  as
# words =  old
# words =  pickup
# words =  skidding
# words =  completely
# words =  out
# words =  control
# words =  on
# words =  long
# words =  patch
# words =  of
# words =  ice
#
#  ['aimless', 'an', 'old', 'pickup', 'skidding', 'completely', 'control', 'a', 'long', 'patch', 'of', 'black', 'ice']
#
# word:  an positive:  11
# word:  a positive:  27
# word:  of positive:  5
# aimless
# old
# pickup
# skidding
# completely
# control
# patch
# black
# ice
# words =  this
# words =  work
# words =  falls
# words =  flat
# words =  in
# words =  about
# words =  conceivable
# words =  area
#
#  ['wretched', 'work', 'falls', 'flat', 'just', 'every', 'conceivable', 'area']
#
# word:  work positive:  11
# word:  just negative:  5
# word:  every positive:  4
# wretched
# falls
# flat
# conceivable
# area
# words =  it
# words =  a
# words =  of
# words =  ride
# words =  samuel
# words =  l
# words =  jackson
# words =  is
# words =  one
# words =  the
# words =  actors
# words =  there
#
#  ['s', 'heck', 'a', 'ride', 'samuel', 'l', 'jackson', 'is', 'of', 'best', 'actors', 'is']
#
# word:  s negative:  29
# word:  a positive:  28
# word:  ride positive:  1
# word:  is positive:  52
# word:  of positive:  6
# word:  best positive:  24
# word:  actors positive:  2
# word:  is positive:  52
# heck
# samuel
# l
# jackson
# words =  inconsistent
# words =  meandering
# words =  and
# words =  dry
# words =  plot
#
#  ['inconsistent', 'meandering', 'sometimes', 'dry', 'plot']
#
# word:  sometimes positive:  1
# inconsistent
# meandering
# dry
# plot
# words =  calling
# words =  this
# words =  brainless
# words =  would
# words =  paying
# words =  it
# words =  compliment
#
#  ['calling', 'movie', 'brainless', 'be', 'paying', 'a', 'compliment']
#
# word:  movie positive:  25
# word:  be positive:  3
# word:  a positive:  29
# calling
# brainless
# paying
# compliment
# words =  adultery
#
#  ['adultery']
#
# score =  0
# words =  appalling
#
#  ['appalling']
#
# word:  appalling negative:  2
# words =  s
# words =  a
# words =  overused
# words =  cocktail
# words =  using
# words =  the
# words =  olives
# words =  since
# words =  1962
# words =  as
# words =  not
# words =  is
# words =  entry
# words =  number
# words =  twenty
# words =  the
# words =  of
# words =  brosnan
# words =  bunch
#
#  ['s', 'stale', 'overused', 'cocktail', 'using', 'same', 'olives', 'since', '1962', 'garnish', 'only', 'is', 'entry', 'number', 'twenty', 'worst', 'the', 'brosnan', 'bunch']
#
# word:  s negative:  29
# word:  stale positive:  1
# word:  since negative:  1
# word:  only positive:  2
# word:  is positive:  54
# word:  worst negative:  9
# word:  the positive:  64
# overused
# cocktail
# using
# same
# olives
# 1962
# garnish
# entry
# number
# twenty
# brosnan
# bunch
# words =  it
# words =  rare
# words =  to
# words =  a
# words =  that
# words =  the
# words =  challenges
# words =  the
# words =  and
# words =  our
# words =  lust
# words =  for
# words =  action
# words =  but
# words =  report
# words =  delivers
# words =  all
# words =  and
# words =  whole
# words =  lot
# words =  more
#
#  ['s', 'rare', 'find', 'film', 'dazzles', 'eye', 'challenges', 'brain', 'satisfies', 'our', 'lust', 'fastpaced', 'action', 'minority', 'report', 'delivers', 'that', 'a', 'whole', 'lot', 'more']
#
# word:  s negative:  29
# word:  find negative:  1
# word:  film positive:  25
# word:  eye positive:  1
# word:  our positive:  1
# word:  minority positive:  1
# word:  report positive:  1
# word:  that positive:  3
# word:  a positive:  30
# word:  lot positive:  1
# word:  more positive:  3
# rare
# dazzles
# challenges
# brain
# satisfies
# lust
# fastpaced
# delivers
# whole
# words =  demonstrates
# words =  that
# words =  director
# words =  of
# words =  hollywood
# words =  blockbusters
# words =  as
# words =  games
# words =  can
# words =  turn
# words =  out
# words =  small
# words =  personal
# words =  film
# words =  with
# words =  emotional
# words =  wallop
#
#  ['demonstrates', 'the', 'director', 'such', 'hollywood', 'blockbusters', 'patriot', 'games', 'still', 'turn', 'a', 'small', 'personal', 'film', 'an', 'emotional', 'wallop']
#
# word:  the positive:  65
# word:  such positive:  4
# word:  hollywood positive:  2
# word:  still negative:  1
# word:  a positive:  31
# word:  small positive:  1
# word:  film positive:  26
# word:  an positive:  12
# word:  emotional negative:  1
# demonstrates
# blockbusters
# patriot
# games
# turn
# personal
# wallop
# words =  a
# words =  sequel
# words =  plagued
# words =  by
# words =  old
# words =  familiar
# words =  feeling
# words =  of
# words =  let
# words =  s
# words =  get
# words =  thing
# words =  over
# words =  with
# words =  has
# words =  shown
# words =  up
# words =  the
# words =  time
# words =  place
#
#  ['superfluous', 'sequel', 'plagued', 'that', 'old', 'familiar', 'feeling', '`', 'let', 's', 'this', 'thing', 'over', 'everyone', 'has', 'shown', 'at', 'appointed', 'and', 'place']
#
# word:  sequel positive:  1
# word:  that positive:  4
# word:  old positive:  1
# word:  feeling positive:  1
# word:  s negative:  29
# word:  this positive:  6
# word:  thing positive:  1
# word:  over positive:  1
# word:  has positive:  14
# word:  at negative:  7
# word:  and positive:  2
# word:  place positive:  1
# superfluous
# plagued
# familiar
# let
# everyone
# shown
# appointed
# words =  skip
# words =  this
#
#  ['skip', 'dreck']
#
# score =  0
# words =  that
# words =  movie
# words =  that
# words =  on
# words =  number
# words =  of
# words =  as
# words =  film
# words =  of
# words =  and
# words =  for
# words =  a
# words =  romance
# words =  for
# words =  and
# words =  compelling
# words =  argument
# words =  about
# words =  both
# words =  pro
# words =  and
# words =  for
#
#  ['rare', 'movie', 'works', 'any', 'number', 'levels', 'film', 'magic', 'whimsy', 'children', 'a', 'heartfelt', 'romance', 'teenagers', 'a', 'compelling', 'argument', 'death', 'both', 'pro', 'con', 'adults']
#
# word:  rare positive:  1
# word:  movie positive:  26
# word:  any negative:  8
# word:  number positive:  1
# word:  levels positive:  1
# word:  film positive:  27
# word:  a positive:  32
# word:  romance positive:  1
# word:  a positive:  32
# word:  compelling positive:  1
# works
# magic
# whimsy
# children
# heartfelt
# teenagers
# argument
# death
# both
# pro
# con
# adults
# words =  this
# words =  junk
#
#  ['pathetic', 'junk']
#
# score =  0
# words =  loved
# words =  this
#
#  ['loved', 'film']
#
# word:  film positive:  28
# loved
# words =  achieves
# words =  ultimate
# words =  insignificance
#
#  ['achieves', 'ultimate', 'insignificance']
#
# score =  0
# words =  standing
# words =  in
# words =  shadows
# words =  of
# words =  is
# words =  cultural
# words =  history
# words =  of
# words =  best
# words =  kind
# words =  informative
# words =  revealing
# words =  and
# words =  entertaining
#
#  ['standing', 'the', 'shadows', 'motown', 'is', 'cultural', 'history', 'the', 'best', 'kind', 'informative', 'revealing', 'richly', 'entertaining']
#
# word:  the positive:  66
# word:  is positive:  55
# word:  cultural positive:  1
# word:  history positive:  2
# word:  the positive:  66
# word:  best positive:  25
# word:  kind positive:  2
# word:  entertaining negative:  1
# standing
# shadows
# motown
# informative
# revealing
# richly
# words =  a
# words =  piece
#
#  ['spectacular', 'piece']
#
# word:  piece positive:  3
# spectacular
# words =  was
# words =  that
# words =  nothing
# words =  more
# words =  than
# words =  a
# words =  exercise
# words =  in
# words =  out
# words =  formula
# words =  that
# words =  five
# words =  years
# words =  ago
# words =  but
# words =  since
# words =  lost
# words =  its
# words =  fizz
#
#  ['was', 'movie', 'nothing', 'more', 'than', 'tepid', 'exercise', 'trotting', 'a', 'formula', 'worked', 'five', 'years', 'ago', 'has', 'since', 'lost', 'its', 'fizz']
#
# word:  was positive:  2
# word:  movie positive:  27
# word:  more positive:  4
# word:  than negative:  5
# word:  a positive:  34
# word:  five positive:  1
# word:  has positive:  14
# word:  lost negative:  1
# word:  its positive:  9
# nothing
# tepid
# exercise
# trotting
# formula
# worked
# years
# ago
# fizz
# words =  channel
# words =  5
# words =  grade
# words =  trash
#
#  ['channel', '5', 'grade', 'trash']
#
# score =  0
# words =  a
# words =  nonsensical
# words =  comedy
# words =  about
# words =  city
# words =  coming
# words =  apart
# words =  at
# words =  seams
#
#  ['deliciously', 'nonsensical', 'comedy', 'a', 'city', 'coming', 'apart', 'its', 'seams']
#
# word:  comedy negative:  7
# word:  a positive:  35
# word:  its positive:  10
# deliciously
# nonsensical
# city
# coming
# apart
# seams
# words =  degenerates
# words =  into
# words =  hogwash
#
#  ['degenerates', 'into', 'hogwash']
#
# word:  into negative:  4
# degenerates
# hogwash
# words =  in
# words =  visuals
#
#  ['gorgeous', 'visuals']
#
# score =  0
# words =  would
# words =  matter
# words =  so
# words =  that
# words =  arrogant
# words =  richard
# words =  pryor
# words =  wannabe
# words =  s
# words =  routine
# words =  is
# words =  offensive
# words =  puerile
# words =  and
# words =  foulmouthed
# words =  if
# words =  was
# words =  at
# words =  funny
#
#  ['nt', 'matter', 'much', 'this', 'arrogant', 'richard', 'pryor', 'wannabe', 's', 'routine', 'is', 'offensive', 'puerile', 'unimaginatively', 'foulmouthed', 'it', 'was', 'least', 'funny']
#
# word:  nt positive:  8
# word:  matter negative:  1
# word:  this positive:  6
# word:  s negative:  30
# word:  is positive:  56
# word:  it positive:  8
# word:  was positive:  3
# word:  least positive:  3
# word:  funny positive:  2
# arrogant
# richard
# pryor
# wannabe
# routine
# offensive
# puerile
# unimaginatively
# foulmouthed
# words =  that
# words =  her
# words =  the
# words =  echelons
# words =  of
# words =  directing
# words =  world
#
#  ['propels', 'into', 'upper', 'echelons', 'the', 'directing', 'world']
#
# word:  into negative:  5
# word:  the positive:  68
# word:  world positive:  2
# propels
# upper
# echelons
# directing
# words =  ll
# words =  find
# words =  yourself
# words =  remembering
# words =  this
# words =  visit
# words =  to
# words =  sunshine
# words =  state
#
#  ['ll', 'find', 'yourself', 'remembering', 'refreshing', 'visit', 'a', 'sunshine', 'state']
# word:  ll positive:  4
# word:  refreshing positive:  1
# word:  a positive:  36
# yourself
# remembering
# visit
# sunshine
# state
# words =  there
# words =  no
# words =  the
#
#  ['s', 'saving', 'movie']
#
# word:  s negative:  30
# word:  movie positive:  28
# saving
# words =  idiots
# words =  who
# words =  nt
# words =  care
# words =  what
# words =  of
# words =  they
# words =  into
# words =  their
# words =  gullets
# words =  to
# words =  sustenance
#
#  ['idiots', 'do', 'nt', 'care', 'kind', 'sewage', 'shovel', 'into', 'mental', 'gullets', 'simulate', 'sustenance']
#
# word:  do positive:  2
# word:  nt positive:  9
# word:  kind positive:  3
# word:  into negative:  5
# idiots
# care
# sewage
# shovel
# mental
# gullets
# simulate
# sustenance
# words =  plays
# words =  like
# words =  extended
# words =  dialogue
# words =  exercise
# words =  in
# words =  101
#
#  ['plays', 'an', 'extended', 'dialogue', 'exercise', 'retard', '101']
#
# word:  plays positive:  1
# word:  an positive:  13
# word:  dialogue positive:  1
# word:  exercise positive:  1
# extended
# retard
# 101
# words =  you
# words =  wasted
# words =  nearly
# words =  two
# words =  hours
# words =  of
# words =  own
# words =  precious
# words =  life
# words =  with
# words =  silly
# words =  little
# words =  puddle
# words =  of
# words =  movie
#
#  ['ve', 'wasted', 'nearly', 'two', 'hours', 'your', 'own', 'precious', 'life', 'this', 'silly', 'little', 'puddle', 'a', 'movie']
#
# word:  nearly positive:  3
# word:  hours positive:  1
# word:  your positive:  3
# word:  own positive:  4
# word:  life positive:  2
# word:  this positive:  7
# word:  silly negative:  1
# word:  little positive:  3
# word:  a positive:  37
# word:  movie positive:  28
# ve
# wasted
# precious
# puddle
# words =  played
# words =  out
# words =  such
# words =  aching
# words =  beauty
# words =  and
# words =  that
# words =  brings
# words =  tears
# words =  to
# words =  eyes
#
#  ['played', 'with', 'such', 'aching', 'beauty', 'truth', 'it', 'brings', 'tears', 'your', 'eyes']
#
# word:  with positive:  1
# word:  such positive:  5
# word:  beauty positive:  1
# word:  it positive:  9
# word:  your positive:  4
# played
# aching
# truth
# brings
# tears
# eyes
# words =  meeting
# words =  even
# words =  exceeding
# words =  expectations
# words =  it
# words =  the
# words =  sequel
# words =  since
# words =  the
# words =  strikes
# words =  back
# words =  a
# words =  achievement
# words =  an
# words =  of
# words =  grandeur
# words =  and
# words =  emotional
# words =  depth
#
#  ['meeting', 'even', 'exceeding', 'expectations', 's', 'best', 'sequel', 'since', 'empire', 'strikes', 'back', 'majestic', 'achievement', 'epic', 'astonishing', 'grandeur', 'surprising', 'emotional', 'depth']
#
# word:  even positive:  6
# word:  s negative:  31
# word:  best positive:  26
# word:  since positive:  2
# word:  back negative:  2
# word:  surprising negative:  1
# score =  0
# words =  one
# words =  the
# words =  plain
# words =  unimaginative
# words =  romantic
# words =  comedies
# words =  i
#
#  ['of', 'most', 'plain', 'unimaginative', 'romantic', 'comedies', 'i']
#
# word:  of positive:  7
# word:  most positive:  21
# word:  romantic positive:  1
# word:  comedies positive:  3
# word:  i negative:  21
# plain
# unimaginative
# words =  too
# words =  thanks
# words =  to
# words =  credible
# words =  performances
# words =  from
# words =  whole
# words =  cast
#
#  ['too', 'thanks', 'strong', 'credible', 'performances', 'the', 'whole', 'cast']
#
# word:  too positive:  2
# word:  performances positive:  6
# word:  the positive:  69
# word:  whole positive:  1
# word:  cast positive:  1
# thanks
# strong
# credible
# words =  upper
# words =  west
# words =  sidey
# words =  exercise
# words =  in
# words =  and
# words =  disguised
# words =  as
# words =  tribute
#
#  ['upper', 'west', 'sidey', 'exercise', 'narcissism', 'selfcongratulation', 'disguised', 'a', 'tribute']
#
# word:  upper positive:  1
# word:  exercise positive:  2
# word:  a positive:  38
# west
# sidey
# narcissism
# selfcongratulation
# disguised
# tribute
# words =  became
# words =  mad
# words =  that
# words =  wasted
# words =  123
# words =  minutes
# words =  and
# words =  on
# words =  21st
# words =  century
#
#  ['became', 'mad', 'i', 'wasted', '123', 'minutes', '950', 'this', '21st', 'century']
#
# word:  i negative:  21
# word:  wasted positive:  1
# word:  this positive:  8
# became
# mad
# 123
# minutes
# 950
# 21st
# century
# words =  a
# words =  date
# words =  movie
#
#  ['terrific', 'date', 'movie']
#
# word:  movie positive:  29
# terrific
# date
# words =  a
# words =  wreck
# words =  of
# words =  action
# words =  film
#
#  ['train', 'wreck', 'an', 'action', 'film']
#
# word:  an positive:  14
# word:  action positive:  2
# word:  film positive:  29
# train
# wreck
# words =  scathing
# words =  and
# words =  it
# words =  a
#
#  ['scathing', 'joyous', 's', 'masterpeice']
#
# word:  s negative:  31
# scathing
# joyous
# masterpeice
# words =  that
# words =  s
# words =  no
# words =  in
# words =  antonio
# words =  banderaslucy
# words =  liu
# words =  faceoff
# words =  it
# words =  still
# words =  terrible
#
#  ['there', 's', 'plot', 'this', 'antonio', 'banderaslucy', 'liu', 'faceoff', 's', 'still', 'terrible']
#
# word:  there negative:  2
# word:  s negative:  32
# word:  plot positive:  1
# word:  this positive:  8
# word:  s negative:  32
# antonio
# banderaslucy
# liu
# faceoff
# terrible
# words =  ballistic
# words =  ecks
# words =  vs
# words =  sever
# words =  also
# words =  features
# words =  terrible
# words =  banal
# words =  dialogue
# words =  convenient
# words =  holeridden
# words =  plotting
# words =  superficial
# words =  characters
# words =  and
# words =  rather
# words =  dull
# words =  unimaginative
# words =  car
# words =  chase
#
#  ['ballistic', 'ecks', 'vs', 'sever', 'also', 'features', 'terrible', 'banal', 'dialogue', 'convenient', 'holeridden', 'plotting', 'superficial', 'characters', 'a', 'rather', 'dull', 'unimaginative', 'car', 'chase']
#
# word:  also negative:  1
# word:  terrible negative:  1
# word:  dialogue positive:  2
# word:  a positive:  39
# word:  rather positive:  3
# word:  dull positive:  2
# word:  unimaginative positive:  1
# word:  chase positive:  2
# ballistic
# ecks
# vs
# sever
# features
# banal
# convenient
# holeridden
# plotting
# superficial
# car
# words =  a
# words =  and
# words =  disaster
#
#  ['critical', 'commercial', 'disaster']
#
# word:  disaster negative:  1
# critical
# commercial
# words =  the
# words =  teenage
# words =  american
# words =  roadtrip
# words =  drek
# words =  we
# words =  seen
# words =  before
#
#  ['same', 'teenage', 'american', 'roadtrip', 'drek', 've', 'seen', 'before']
#
# word:  same positive:  1
# word:  american positive:  1
# word:  ve positive:  1
# word:  seen positive:  2
# word:  before positive:  1
# teenage
# roadtrip
# drek
# words =  they
# words =  put
# words =  to
# words =  by
# words =  movie
# words =  and
# words =  a
#
#  ['were', 'put', 'sleep', 'the', 'movie', 'had', 'nightmare']
#
# word:  were negative:  1
# word:  put positive:  1
# word:  sleep positive:  1
# word:  the positive:  70
# word:  movie positive:  30
# word:  had negative:  2
# nightmare
# words =  the
# words =  tired
# words =  old
# words =  gags
# words =  modernized
# words =  for
# words =  extreme
# words =  sports
# words =  generation
# words =  there
# words =  already
# words =  been
# words =  too
# words =  many
# words =  of
# words =  films
#
#  ['same', 'tired', 'old', 'gags', 'modernized', 'the', 'extreme', 'sports', 'generation', 's', 'already', 'been', 'too', 'many', 'these', 'films']
#
# word:  same positive:  2
# word:  tired positive:  1
# word:  the positive:  71
# word:  extreme negative:  1
# word:  s negative:  34
# word:  been positive:  1
# word:  too positive:  3
# word:  many positive:  1
# word:  these positive:  1
# word:  films positive:  13
# gags
# modernized
# sports
# generation
# already
# words =  far
# words =  superior
#
#  ['far', 'superior']
#
# score =  0
# words =  cinematic
# words =  intoxication
# words =  a
# words =  inventive
# words =  mixture
# words =  of
# words =  and
# words =  tastelessness
# words =  and
# words =  elegance
#
#  ['cinematic', 'intoxication', 'wildly', 'inventive', 'mixture', 'comedy', 'melodrama', 'tastelessness', 'swooning', 'elegance']
#
# word:  inventive positive:  1
# word:  comedy negative:  7
# word:  elegance positive:  1
# intoxication
# wildly
# mixture
# melodrama
# tastelessness
# swooning
# words =  love
# words =  him
#
#  ['love']
#
# word:  love positive:  9
# words =  after
# words =  seeing
# words =  the
# words =  i
# words =  can
# words =  you
# words =  there
# words =  no
# words =  reason
# words =  why
# words =  anyone
# words =  should
# words =  bother
# words =  remembering
# words =  it
#
#  ['after', 'seeing', 'film', 'i', 'tell', 'that', 's', 'other', 'reason', 'why', 'anyone', 'should', 'bother', 'remembering']
#
# word:  film positive:  30
# word:  i negative:  22
# word:  that positive:  4
# word:  s negative:  34
# word:  reason positive:  1
# word:  why positive:  1
# word:  anyone positive:  4
# word:  should positive:  2
# word:  remembering positive:  1
# after
# seeing
# tell
# bother
# words =  one
# words =  the
# words =  exciting
# words =  action
# words =  films
# words =  to
# words =  out
# words =  china
# words =  in
# words =  years
#
#  ['of', 'most', 'exciting', 'action', 'films', 'come', 'of', 'china', 'recent', 'years']
#
# word:  of positive:  8
# word:  most positive:  22
# word:  exciting positive:  1
# word:  action positive:  3
# word:  films positive:  14
# word:  come negative:  1
# word:  of positive:  8
# word:  recent positive:  6
# word:  years positive:  1
# china
# words =  whether
# words =  it
# words =  the
# words =  movie
# words =  of
# words =  i
# words =  ca
# words =  nt
# words =  say
# words =  sure
# words =  memories
# words =  of
# words =  have
# words =  and
# words =  skipped
# words =  country
# words =  bears
# words =  but
# words =  new
# words =  jangle
# words =  of
# words =  mayhem
# words =  and
# words =  must
# words =  be
# words =  serious
# words =  contender
# words =  for
# words =  title
#
#  ['whether', 's', 'worst', 'movie', '2002', 'i', 'ca', 'nt', 'sure', 'memories', 'rollerball', 'faded', 'i', 'skipped', 'country', 'bears', 'this', 'new', 'jangle', 'noise', 'mayhem', 'stupidity', 'must', 'a', 'serious', 'contender', 'for', 'the', 'title']
#
# word:  s negative:  35
# word:  worst negative:  9
# word:  movie positive:  31
# word:  2002 positive:  2
# word:  i negative:  23
# word:  ca negative:  1
# word:  nt positive:  10
# word:  i negative:  23
# word:  this positive:  8
# word:  mayhem negative:  1
# word:  a positive:  40
# word:  the positive:  72
# word:  title positive:  1
# whether
# sure
# memories
# rollerball
# faded
# skipped
# country
# bears
# jangle
# noise
# stupidity
# must
# serious
# contender
# words =  it
# words =  almost
# words =  impossible
# words =  not
# words =  be
# words =  away
# words =  by
# words =  sheer
# words =  beauty
# words =  of
# words =  images
#
#  ['s', 'almost', 'impossible', 'to', 'swept', 'away', 'the', 'sheer', 'beauty', 'his', 'images']
#
# word:  s negative:  35
# word:  almost positive:  3
# word:  impossible positive:  1
# word:  to positive:  6
# word:  swept positive:  1
# word:  away positive:  1
# word:  the positive:  73
# word:  sheer positive:  1
# word:  beauty positive:  2
# word:  his positive:  11
# word:  images positive:  1
# words =  obnoxious
# words =  88minute
# words =  infomercial
#
#  ['obnoxious', '88minute', 'infomercial']
#
# score =  0
# words =  of
# words =  writing
# words =  bad
# words =  direction
# words =  and
# words =  acting
# words =  the
# words =  of
#
#  ['bad', 'writing', 'bad', 'direction', 'bad', 'acting', 'trifecta', 'badness']
#
# word:  bad negative:  22
# word:  writing positive:  1
# word:  bad negative:  22
# word:  direction positive:  3
# word:  bad negative:  22
# word:  acting positive:  2
# trifecta
# badness
# words =  director
# words =  juan
# words =  jose
# words =  campanella
# words =  could
# words =  have
# words =  this
# words =  an
# words =  retread
# words =  of
# words =  iris
# words =  or
# words =  american
# words =  beauty
# words =  but
# words =  pulls
# words =  a
# words =  from
# words =  film
# words =  and
# words =  something
# words =  more
# words =  beautiful
# words =  than
# words =  either
# words =  of
# words =  films
#
#  ['director', 'juan', 'jose', 'campanella', 'could', 'turned', 'into', 'argentine', 'retread', '``', 'iris', '``', 'american', 'beauty', 'instead', 'pulls', 'little', 'each', 'film', 'creates', 'something', 'more', 'beautiful', 'than', 'either', 'those', 'films']
#
# word:  director positive:  2
# word:  could positive:  2
# word:  turned positive:  1
# word:  into negative:  5
# word:  retread positive:  1
# word:  `` positive:  1
# word:  `` positive:  1
# word:  american positive:  2
# word:  beauty positive:  3
# word:  little positive:  4
# word:  each positive:  2
# word:  film positive:  30
# word:  something positive:  6
# word:  more positive:  5
# word:  beautiful positive:  1
# word:  films positive:  15
# juan
# jose
# campanella
# argentine
# iris
# instead
# pulls
# creates
# either
# words =  arguably
# words =  the
# words =  script
# words =  that
# words =  has
# words =  written
# words =  in
#
#  ['arguably', 'best', 'script', 'besson', 'has', 'written', 'years']
#
# word:  best positive:  26
# word:  has positive:  15
# word:  years positive:  2
# arguably
# besson
# written
# words =  one
# words =  those
# words =  terrific
# words =  documentaries
# words =  that
# words =  a
# words =  of
# words =  who
# words =  enthusiastic
# words =  about
# words =  and
# words =  figures
# words =  out
# words =  to
# words =  us
# words =  share
# words =  their
#
#  ['those', 'terrific', 'documentaries', 'collect', 'bunch', 'of', 'people', 'are', 'enthusiastic', 'something', 'then', 'figures', 'how', 'make', 'us', 'share', 'enthusiasm']
#
# word:  those positive:  2
# word:  terrific positive:  1
# word:  bunch positive:  1
# word:  of positive:  10
# word:  people negative:  2
# word:  are positive:  21
# word:  something positive:  7
# word:  how negative:  2
# word:  make positive:  2
# documentaries
# collect
# enthusiastic
# then
# figures
# share
# enthusiasm
# words =  extremely
# words =  boring
#
#  ['extremely', 'boring']
#
# word:  extremely negative:  3
# words =  this
# words =  the
# words =  movie
# words =  experience
#
#  ['is', 'ultimate', 'movie', 'experience']
#
# word:  is positive:  57
# word:  movie positive:  32
# word:  experience negative:  2
# ultimate
# words =  powerful
# words =  enough
# words =  to
# words =  the
# words =  sizzling
# words =  with
#
#  ['powerful', 'enough', 'leave', 'screen', 'sizzling', 'intrigue']
#
# word:  powerful positive:  2
# word:  enough negative:  6
# word:  leave negative:  2
# word:  screen positive:  1
# sizzling
# intrigue
# words =  the
# words =  is
# words =  dreary
# words =  and
#
#  ['update', 'is', 'dreary', 'sluggish']
#
# word:  is positive:  58
# word:  dreary negative:  1
# update
# sluggish
# words =  plodding
# words =  poorly
# words =  written
# words =  murky
# words =  and
# words =  acted
# words =  the
# words =  feels
# words =  as
# words =  everyone
# words =  making
# words =  it
# words =  their
# words =  mojo
#
#  ['plodding', 'poorly', 'written', 'murky', 'weakly', 'acted', 'picture', 'feels', 'if', 'everyone', 'making', 'lost', 'movie', 'mojo']
#
# word:  poorly positive:  2
# word:  written positive:  1
# word:  acted positive:  1
# word:  picture positive:  3
# word:  if negative:  5
# word:  everyone negative:  1
# word:  making positive:  2
# word:  movie positive:  33
# plodding
# murky
# weakly
# feels
# mojo
# words =  if
# words =  is
# words =  cinema
# words =  i
# words =  pledge
# words =  allegiance
# words =  to
# words =  and
#
#  ['this', 'is', 'cinema', 'i', 'pledge', 'allegiance', 'cagney', 'lacey']
#
# word:  this positive:  9
# word:  is positive:  59
# word:  cinema positive:  7
# word:  i negative:  23
# pledge
# allegiance
# cagney
# lacey
# words =  hollywood
# words =  ending
# words =  is
# words =  the
# words =  disappointing
# words =  woody
# words =  allen
# words =  movie
# words =  ever
# words =  he
# words =  a
# words =  cast
# words =  and
# words =  great
# words =  idea
# words =  but
# words =  execution
# words =  is
# words =  a
# words =  with
# words =  exception
# words =  of
# words =  six
# words =  gags
# words =  that
# words =  work
#
#  ['hollywood', 'ending', 'is', 'most', 'disappointing', 'woody', 'allen', 'movie', 'ever', 'has', 'great', 'cast', 'great', 'idea', 'the', 'execution', 'is', 'a', 'flop', 'the', 'exception', 'about', 'six', 'gags', 'really', 'work']
#
# word:  hollywood positive:  3
# word:  ending positive:  1
# word:  is positive:  60
# word:  most positive:  23
# word:  movie positive:  34
# word:  ever positive:  3
# word:  has positive:  16
# word:  great positive:  9
# word:  cast positive:  2
# word:  great positive:  9
# word:  the positive:  74
# word:  execution positive:  1
# word:  is positive:  60
# word:  a positive:  41
# word:  the positive:  74
# word:  about negative:  6
# word:  gags positive:  1
# word:  really negative:  2
# word:  work positive:  12
# disappointing
# woody
# allen
# flop
# exception
# six
# words =  i
# words =  did
# words =  nt
# words =  laugh
# words =  i
# words =  did
# words =  nt
# words =  smile
#
#  ['i', 'did', 'nt', 'laugh', 'i', 'did', 'nt', 'smile']
#
# word:  i negative:  23
# word:  nt positive:  11
# word:  laugh positive:  1
# word:  i negative:  23
# word:  nt positive:  11
# did
# smile
# words =  onesided
# words =  documentary
# words =  offers
# words =  simplistic
# words =  explanations
# words =  to
# words =  very
# words =  complex
# words =  situation
# words =  stylistically
# words =  the
# words =  is
# words =  a
#
#  ['onesided', 'documentary', 'offers', 'simplistic', 'explanations', 'very', 'complex', 'situation', 'stylistically', 'movie', 'is', 'a', 'disaster']
#
# word:  documentary positive:  1
# word:  very positive:  2
# word:  complex positive:  1
# word:  situation negative:  1
# word:  movie positive:  35
# word:  is positive:  62
# word:  a positive:  42
# word:  disaster negative:  2
# onesided
# offers
# simplistic
# explanations
# stylistically
# words =  me
# words =  to
# words =  the
# words =  in
# words =  first
# words =  10
# words =  minutes
#
#  ['want', 'bolt', 'theater', 'the', 'first', '10', 'minutes']
#
# word:  want negative:  5
# word:  theater negative:  2
# word:  the positive:  76
# word:  first positive:  8
# word:  minutes negative:  1
# bolt
# 10
# words =  good
# words =  car
# words =  chases
# words =  great
# words =  fight
# words =  scenes
#
#  ['good', 'car', 'chases', 'great', 'fight', 'scenes']
#
# word:  good positive:  2
# word:  car positive:  1
# word:  chases positive:  1
# word:  great positive:  11
# word:  scenes positive:  1
# fight
# words =  you
# words =  have
# words =  wonder
# words =  how
# words =  on
# words =  anyone
# words =  anywhere
# words =  could
# words =  have
# words =  they
# words =  make
# words =  guffaw
# words =  with
# words =  script
# words =  as
# words =  diabolical
# words =  as
#
#  ['really', 'to', 'wonder', 'how', 'earth', 'anyone', 'anywhere', 'could', 'thought', 'd', 'audiences', 'guffaw', 'a', 'script', 'utterly', 'diabolical', 'this']
#
# word:  really negative:  2
# word:  to positive:  7
# word:  wonder negative:  1
# word:  how negative:  2
# word:  anyone positive:  4
# word:  could positive:  3
# word:  d positive:  1
# word:  audiences positive:  1
# word:  a positive:  43
# word:  script positive:  2
# word:  utterly positive:  2
# word:  this positive:  10
# earth
# anywhere
# thought
# guffaw
# diabolical
# words =  for
# words =  movies
# words =  84
# words =  minutes
# words =  is
# words =  short
# words =  but
# words =  one
# words =  like
# words =  life
# words =  sentence
#
#  ['most', 'movies', '84', 'minutes', 'is', 'short', 'this', 'feels', 'a', 'life', 'sentence']
#
# word:  most positive:  24
# word:  movies positive:  1
# word:  is positive:  63
# word:  this positive:  11
# word:  feels positive:  1
# word:  a positive:  44
# word:  life positive:  3
# 84
# short
# sentence
# words =  it
# words =  simply
# words =  stupid
# words =  irrelevant
# words =  and
# words =  truly
# words =  bottomlessly
# words =  cynical
#
#  ['s', 'simply', 'stupid', 'irrelevant', 'deeply', 'truly', 'bottomlessly', 'cynical']
#
# word:  s negative:  35
# word:  simply positive:  2
# word:  deeply positive:  1
# word:  truly positive:  1
# stupid
# irrelevant
# bottomlessly
# cynical
# words =  rank
# words =  as
# words =  of
# words =  most
# words =  multilayered
# words =  and
# words =  female
# words =  characters
# words =  of
# words =  year
#
#  ['rank', 'three', 'the', 'most', 'multilayered', 'sympathetic', 'female', 'characters', 'the', 'year']
#
# word:  rank positive:  1
# word:  the positive:  77
# word:  most positive:  25
# word:  characters positive:  2
# word:  the positive:  77
# word:  year positive:  6
# three
# multilayered
# sympathetic
# female
# words =  a
# words =  of
# words =  movie
# words =  visually
# words =  unattractive
# words =  unbearably
# words =  loud
# words =  and
# words =  silly
#
#  ['shambles', 'a', 'movie', 'visually', 'unattractive', 'unbearably', 'loud', 'utterly', 'silly']
#
# word:  a positive:  45
# word:  movie positive:  36
# word:  visually positive:  2
# word:  utterly positive:  3
# shambles
# unattractive
# unbearably
# loud
# words =  one
# words =  the
# words =  great
# words =  apocalypse
# words =  movies
#
#  ['of', 'alltime', 'great', 'apocalypse', 'movies']
#
# word:  of positive:  11
# word:  great positive:  12
# word:  movies positive:  2
# alltime
# apocalypse
# words =  emerge
# words =  as
# words =  exquisite
# words =  motion
# words =  picture
# words =  in
# words =  own
# words =  right
#
#  ['emerge', 'an', 'exquisite', 'motion', 'picture', 'its', 'own', 'right']
#
# word:  emerge positive:  1
# word:  an positive:  15
# word:  exquisite positive:  2
# word:  motion positive:  1
# word:  picture positive:  4
# word:  its positive:  11
# word:  own positive:  5
# words =  have
# words =  one
# words =  the
# words =  daring
# words =  and
# words =  american
# words =  movies
# words =  of
# words =  year
#
#  ['been', 'more', 'daring', 'surprising', 'american', 'movies', 'of', 'the', 'year']
#
# word:  been positive:  2
# word:  more positive:  6
# word:  daring positive:  1
# word:  surprising negative:  1
# word:  american positive:  3
# word:  movies positive:  3
# word:  of positive:  12
# word:  the positive:  79
# word:  year positive:  7
# words =  laughed
# words =  that
# words =  in
#
#  ['laughed', 'hard', 'years']
#
# word:  laughed positive:  1
# word:  hard positive:  1
# word:  years positive:  3
# words =  slap
# words =  her
# words =  s
# words =  not
# words =  no
# words =  people
# words =  were
# words =  harmed
# words =  during
# words =  the
# words =  of
# words =  movie
# words =  but
# words =  were
# words =  insulted
# words =  and
# words =  audience
# words =  was
# words =  put
# words =  through
# words =  torture
# words =  for
# words =  hour
# words =  and
# words =  half
#
#  ['slap', 'she', 's', 'funny', 'french', 'people', 'were', 'harmed', 'during', 'making', 'this', 'movie', 'they', 'were', 'insulted', 'the', 'audience', 'was', 'put', 'through', 'torture', 'an', 'hour', 'a', 'half']
#
# word:  s negative:  36
# word:  funny positive:  3
# word:  people negative:  2
# word:  during positive:  1
# word:  making positive:  3
# word:  this positive:  12
# word:  movie positive:  37
# word:  they positive:  1
# word:  the positive:  80
# word:  was positive:  4
# word:  put positive:  2
# word:  through positive:  4
# word:  torture positive:  1
# word:  an positive:  16
# word:  hour positive:  1
# word:  a positive:  46
# word:  half positive:  1
# slap
# she
# french
# harmed
# insulted
# audience
# words =  this
# words =  observed
# words =  story
# words =  deeply
# words =  felt
# words =  and
# words =  stylized
#
#  ['delicately', 'observed', 'story', 'deeply', 'felt', 'masterfully', 'stylized']
#
# word:  story positive:  6
# delicately
# observed
# felt
# masterfully
# stylized
# words =  the
# words =  is
# words =  fascinating
# words =  the
# words =  is
# words =  dazzling
#
#  ['history', 'is', 'fascinating', 'action', 'is', 'dazzling']
#
# word:  history positive:  3
# word:  is positive:  64
# word:  fascinating positive:  3
# word:  action positive:  4
# word:  is positive:  64
# word:  dazzling positive:  1
# words =  a
# words =  movie
#
#  ['terrible', 'movie']
#
# word:  movie positive:  38
# words =  thanks
# words =  to
# words =  filmmaking
# words =  and
# words =  pair
# words =  of
# words =  performances
#
#  ['thanks', 'confident', 'filmmaking', 'a', 'pair', 'fascinating', 'performances']
#
# word:  thanks positive:  1
# word:  filmmaking positive:  7
# word:  a positive:  47
# word:  fascinating positive:  4
# word:  performances positive:  7
# confident
# pair
# words =  any
# words =  of
# words =  performances
# words =  as
#
#  ['any', 'these', 'performances', 'awardworthy']
#
# word:  any negative:  8
# word:  these positive:  2
# word:  performances positive:  8
# awardworthy
# words =  one
# words =  those
# words =  rare
# words =  docs
# words =  that
# words =  a
# words =  picture
# words =  of
# words =  era
# words =  and
# words =  the
# words =  feel
# words =  like
# words =  party
#
#  ['those', 'rare', 'docs', 'paints', 'grand', 'picture', 'of', 'an', 'era', 'makes', 'journey', 'feel', 'a', 'party']
#
# word:  those positive:  3
# word:  rare positive:  2
# word:  picture positive:  5
# word:  of positive:  13
# word:  an positive:  17
# word:  era positive:  1
# word:  makes positive:  2
# word:  feel positive:  1
# word:  a positive:  48
# docs
# paints
# grand
# journey
# party
# words =  it
# words =  drab
# words =  it
# words =  uninteresting
#
#  ['s', 'drab', 's', 'uninteresting']
#
# word:  s negative:  36
# word:  s negative:  36
# word:  uninteresting negative:  1
# drab
# words =  a
# words =  scam
# words =  put
# words =  together
# words =  by
# words =  cynical
# words =  creeps
# words =  at
# words =  studios
# words =  and
# words =  entertainment
# words =  to
# words =  the
# words =  out
# words =  surrender
# words =  9
# words =  and
# words =  minutes
# words =  of
# words =  life
#
#  ['cheap', 'scam', 'put', 'together', 'some', 'cynical', 'creeps', 'revolution', 'studios', 'imagine', 'entertainment', 'make', 'suckers', 'there', 'surrender', '9', '93', 'minutes', 'unrecoverable', 'life']
#
# word:  put positive:  3
# word:  cynical negative:  1
# word:  studios negative:  1
# word:  imagine positive:  1
# word:  make positive:  3
# word:  there negative:  3
# word:  minutes positive:  2
# word:  life positive:  4
# cheap
# scam
# together
# creeps
# revolution
# entertainment
# suckers
# surrender
# 9
# 93
# unrecoverable
# words =  i
# words =  can
# words =  infantile
# words =  humor
# words =  but
# words =  is
# words =  the
# words =  of
# words =  that
# words =  you
# words =  about
# words =  the
# words =  and
# words =  s
# words =  diapers
#
#  ['i', 'take', 'infantile', 'humor', 'this', 'is', 'sort', 'infantile', 'makes', 'wonder', 'changing', 'director', 'writer', 's', 'diapers']
#
# word:  i negative:  25
# word:  take positive:  1
# word:  infantile negative:  1
# word:  humor negative:  1
# word:  this positive:  13
# word:  is positive:  66
# word:  infantile negative:  1
# word:  makes positive:  3
# word:  director positive:  3
# word:  writer negative:  1
# word:  s negative:  38
# word:  diapers negative:  1
# sort
# words =  cinema
# words =  s
# words =  finest
# words =  this
#
# ...
# purely
# satisfying
# evenings
# words =  a
# words =  dull
# words =  redundant
# words =  concept
# words =  that
# words =  more
# words =  than
# words =  a
# words =  of
# words =  despite
# words =  iwai
# words =  s
# words =  vaunted
# words =  empathy
#
#  ['woefully', 'dull', 'redundant', 'concept', 'bears', 'more', 'than', 'whiff', 'exploitation', 'despite', 'iwai', 's', 'vaunted', 'empathy']
#
# word:  dull positive:  6
# word:  concept positive:  1
# word:  bears positive:  1
# word:  more positive:  7
# word:  than positive:  6
# word:  s negative:  42
# woefully
# redundant
# whiff
# exploitation
# despite
# iwai
# vaunted
# empathy
# words =  that
# words =  got
# words =  oodles
# words =  of
# words =  and
#
#  ['s', 'got', 'oodles', 'style', 'substance']
#
# word:  s negative:  43
# word:  style positive:  1
# got
# oodles
# substance
# words =  made
# words =  a
# words =  film
# words =  that
# words =  the
# words =  s
# words =  psychology
# words =  not
# words =  order
# words =  to
# words =  him
# words =  rather
# words =  to
# words =  that
# words =  pathology
# words =  evolved
# words =  from
# words =  impulses
# words =  that
# words =  hideously
# words =  twisted
#
#  ['made', 'remarkable', 'film', 'explores', 'monster', 's', 'psychology', 'in', 'order', 'excuse', 'but', 'rather', 'demonstrate', 'his', 'pathology', 'evolved', 'human', 'impulses', 'grew', 'hideously', 'twisted']
#
# word:  made positive:  4
# word:  remarkable positive:  2
# word:  film positive:  36
# word:  s negative:  44
# word:  in positive:  2
# word:  order positive:  1
# word:  rather positive:  4
# word:  demonstrate positive:  1
# word:  his positive:  12
# word:  human negative:  1
# word:  twisted negative:  1
# explores
# monster
# psychology
# excuse
# but
# pathology
# evolved
# impulses
# grew
# hideously
# words =  is
# words =  hollow
# words =  selfindulgent
# words =  and
# words =  of
# words =  boring
#
#  ['is', 'hollow', 'selfindulgent', 'worst', 'all', 'boring']
#
# word:  is positive:  79
# word:  hollow positive:  1
# word:  selfindulgent positive:  1
# word:  worst negative:  9
# word:  all positive:  9
# word:  boring negative:  2
# words =  is
# words =  a
# words =  of
# words =  story
# words =  full
# words =  of
# words =  and
# words =  lacking
# words =  in
#
#  ['is', 'disaster', 'a', 'story', 'full', 'holes', 'completely', 'lacking', 'chills']
#
# word:  is positive:  80
# word:  disaster negative:  2
# word:  a positive:  56
# word:  story positive:  9
# word:  full positive:  4
# word:  holes positive:  1
# word:  completely positive:  1
# word:  lacking negative:  1
# chills
# words =  directed
# words =  action
# words =  sequences
# words =  and
# words =  of
# words =  worst
# words =  dialogue
# words =  in
# words =  memory
#
#  ['directed', 'action', 'sequences', 'some', 'the', 'worst', 'dialogue', 'recent', 'memory']
#
# word:  action positive:  6
# word:  some positive:  5
# word:  the positive:  91
# word:  worst negative:  9
# word:  dialogue positive:  4
# word:  recent positive:  7
# directed
# sequences
# memory
# words =  the
# words =  undercover
# words =  brother
# words =  a
# words =  mix
# words =  of
# words =  night
# words =  livestyle
# words =  parody
# words =  70s
# words =  blaxploitation
# words =  films
# words =  and
# words =  action
# words =  comedy
# words =  gone
# words =  wild
# words =  dishes
# words =  out
# words =  ton
# words =  of
# words =  that
# words =  can
#
#  ['enjoyable', 'undercover', 'brother', 'zany', 'mix', 'saturday', 'night', 'livestyle', 'parody', '70s', 'blaxploitation', 'films', 'goofball', 'action', 'comedy', 'gone', 'wild', 'dishes', 'a', 'ton', 'laughs', 'everyone', 'enjoy']
#
# word:  enjoyable positive:  4
# word:  films positive:  17
# word:  action positive:  7
# word:  comedy negative:  8
# word:  a positive:  57
# word:  enjoy positive:  1
# undercover
# brother
# zany
# mix
# saturday
# night
# livestyle
# parody
# 70s
# blaxploitation
# goofball
# gone
# wild
# dishes
# ton
# laughs
# words =  metropolis
# words =  you
# words =  to
# words =  your
# words =  eyes
# words =  away
# words =  from
# words =  images
# words =  long
# words =  enough
# words =  to
# words =  the
#
#  ['metropolis', 'hate', 'tear', 'your', 'eyes', 'away', 'images', 'long', 'enough', 'read', 'the', 'subtitles']
#
# word:  hate negative:  1
# word:  your positive:  5
# word:  eyes positive:  1
# word:  away positive:  2
# word:  images positive:  2
# word:  long positive:  2
# word:  enough negative:  7
# word:  the positive:  92
# metropolis
# tear
# read
# subtitles
# words =  it
# words =  a
# words =  film
#
#  ['is', 'great', 'film']
#
# word:  is positive:  81
# word:  great positive:  13
# word:  film positive:  37
# words =  dreadful
#
#  ['dreadful']
#
# score =  0
# words =  a
# words =  four
# words =  years
# words =  in
# words =  making
#
#  ['masterpiece', 'four', 'years', 'the', 'making']
#
# word:  masterpiece positive:  8
# word:  four positive:  1
# word:  years positive:  5
# word:  the positive:  93
# word:  making positive:  4
# words =  you
# words =  chris
# words =  smith
# words =  s
# words =  next
# words =  movie
#
#  ['crave', 'chris', 'smith', 's', 'next', 'movie']
#
# word:  s negative:  44
# word:  next positive:  1
# word:  movie positive:  42
# crave
# chris
# smith
# words =  rather
# words =  less
# words =  than
# words =  the
# words =  of
# words =  underventilated
# words =  pèrefils
# words =  confrontations
#
#  ['rather', 'less', 'than', 'sum', 'its', 'underventilated', 'pèrefils', 'confrontations']
#
# word:  rather positive:  5
# word:  sum positive:  1
# word:  its positive:  13
# less
# underventilated
# pèrefils
# confrontations
# words =  this
# words =  spoofy
# words =  update
# words =  of
# words =  s
# words =  macbeth
# words =  does
# words =  nt
# words =  sustain
# words =  a
# words =  enough
# words =  level
# words =  of
#
#  ['toolong', 'spoofy', 'update', 'shakespeare', 's', 'macbeth', 'does', 'nt', 'sustain', 'high', 'enough', 'level', 'invention']
#
# word:  update positive:  1
# word:  s negative:  45
# word:  nt positive:  13
# word:  sustain positive:  1
# word:  high negative:  1
# word:  enough negative:  7
# toolong
# spoofy
# shakespeare
# macbeth
# level
# invention
# words =  is
# words =  a
# words =  tourdeforce
# words =  and
# words =  story
# words =  that
# words =  unlike
# words =  any
# words =  you
# words =  likely
# words =  see
# words =  anywhere
# words =  else
#
#  ['is', 'visual', 'tourdeforce', 'a', 'story', 'is', 'unlike', 'any', 'will', 'likely', 'see', 'anywhere', 'else']
#
# word:  is positive:  82
# word:  visual positive:  3
# word:  a positive:  58
# word:  story positive:  10
# word:  is positive:  82
# word:  any negative:  8
# word:  will positive:  5
# word:  see positive:  3
# word:  anywhere positive:  1
# tourdeforce
# unlike
# else
# words =  never
# words =  engaging
# words =  utterly
# words =  predictable
# words =  and
# words =  void
# words =  of
# words =  remotely
# words =  interesting
# words =  or
#
#  ['never', 'engaging', 'utterly', 'predictable', 'completely', 'void', 'anything', 'remotely', 'interesting', 'suspenseful']
#
# word:  never positive:  3
# word:  utterly positive:  4
# word:  predictable negative:  1
# word:  completely positive:  2
# word:  anything positive:  2
# word:  interesting positive:  1
# engaging
# void
# remotely
# suspenseful
# words =  absolutely
# words =  no
#
#  ['absolutely', 'meaning']
#
# word:  absolutely positive:  1
# meaning
# words =  a
# words =  flick
#
#  ['terrific', 'flick']
#
# word:  terrific positive:  2
# word:  flick positive:  1
# words =  his
# words =  are
# words =  acting
# words =  horribly
#
#  ['characters', 'are', 'acting', 'horribly']
#
# word:  characters positive:  3
# word:  are positive:  23
# word:  acting positive:  6
# horribly
# words =  i
# words =  love
# words =  the
# words =  scenes
# words =  of
# words =  wintry
# words =  new
# words =  york
# words =  city
# words =  in
# words =  cinematic
# words =  poetry
# words =  showcases
# words =  the
# words =  s
# words =  oldworld
# words =  charm
# words =  before
# words =  machines
# words =  change
# words =  nearly
# words =  everything
#
#  ['i', 'love', 'opening', 'scenes', 'a', 'wintry', 'new', 'york', 'city', '1899', 'cinematic', 'poetry', 'showcases', 'city', 's', 'oldworld', 'charm', 'before', 'machines', 'change', 'nearly', 'everything']
#
# word:  i negative:  25
# word:  love positive:  10
# word:  scenes positive:  2
# word:  a positive:  59
# word:  new positive:  2
# word:  city positive:  1
# word:  cinematic negative:  2
# word:  poetry positive:  1
# word:  city positive:  1
# word:  s negative:  46
# word:  before positive:  2
# word:  nearly positive:  4
# word:  everything positive:  1
# opening
# wintry
# york
# 1899
# showcases
# oldworld
# charm
# machines
# change
# words =  director
# words =  shekhar
# words =  kapur
# words =  supplies
# words =  with
# words =  skill
#
#  ['director', 'shekhar', 'kapur', 'supplies', 'tremendous', 'skill']
#
# word:  director positive:  4
# shekhar
# kapur
# supplies
# tremendous
# skill
# words =  be
# words =  worst
# words =  film
# words =  a
# words =  has
# words =  made
# words =  about
# words =  since
# words =  valley
# words =  of
# words =  dolls
#
#  ['the', 'worst', 'film', 'man', 'has', 'made', 'women', 'since', 'valley', 'the', 'dolls']
#
# word:  the positive:  94
# word:  film positive:  38
# word:  man positive:  2
# word:  has positive:  19
# word:  made positive:  5
# word:  since positive:  2
# word:  the positive:  94
# women
# valley
# dolls
# words =  oscarworthy
#
#  ['oscarworthy']
#
# score =  0
# words =  one
# words =  the
# words =  romantic
# words =  comedies
#
#  ['of', 'greatest', 'romantic', 'comedies']
#
# word:  of positive:  18
# word:  greatest positive:  1
# word:  romantic positive:  2
# word:  comedies positive:  4
# words =  the
# words =  appeal
# words =  of
# words =  report
# words =  should
# words =  transcend
# words =  any
# words =  awards
# words =  it
# words =  this
# words =  one
# words =  the
#
#  ['longrange', 'appeal', 'minority', 'report', 'should', 'transcend', 'any', 'awards', 'bags', 'is', 'for', 'ages']
#
# word:  appeal positive:  1
# word:  minority positive:  2
# word:  report positive:  2
# word:  should positive:  2
# word:  any negative:  8
# word:  is positive:  84
# word:  for positive:  2
# longrange
# transcend
# awards
# bags
# ages
# words =  is
# words =  about
# words =  worst
# words =  thing
# words =  chan
# words =  has
# words =  done
# words =  in
# words =  united
# words =  states
#
#  ['is', 'the', 'worst', 'thing', 'chan', 'has', 'done', 'the', 'united', 'states']
#
# word:  is positive:  85
# word:  the positive:  96
# word:  worst positive:  10
# word:  has positive:  20
# word:  done negative:  1
# word:  the positive:  96
# chan
# united
# states
# words =  amazing
#
#  ['amazing']
#
# score =  0
# words =  aside
# words =  from
# words =  the
# words =  movie
# words =  of
# words =  year
# words =  simone
# words =  andrew
# words =  niccol
# words =  s
# words =  brilliant
# words =  antihollywood
# words =  satire
# words =  has
# words =  a
# words =  eccentric
# words =  enchantment
# words =  to
#
#  ['aside', 'being', 'funniest', 'movie', 'the', 'year', 'simone', 'andrew', 'niccol', 's', 'brilliant', 'antihollywood', 'satire', 'has', 'wickedly', 'eccentric', 'enchantment', 'it']
#
# word:  being positive:  3
# word:  funniest positive:  2
# word:  movie positive:  42
# word:  the positive:  98
# word:  year positive:  12
# word:  andrew positive:  1
# word:  s negative:  46
# word:  brilliant positive:  12
# word:  has positive:  21
# word:  it positive:  10
# aside
# simone
# niccol
# antihollywood
# satire
# wickedly
# eccentric
# enchantment
# words =  priceless
# words =  entertainment
#
#  ['priceless', 'entertainment']
#
# word:  entertainment positive:  1
# priceless
# words =  fascinating
# words =  and
#
#  ['fascinating']
#
# word:  fascinating positive:  5
# words =  one
# words =  the
# words =  ingenious
# words =  and
# words =  thrillers
# words =  i
# words =  ve
# words =  seen
# words =  in
# words =  a
# words =  time
#
#  ['of', 'most', 'ingenious', 'entertaining', 'thrillers', 'i', 've', 'seen', 'quite', 'long']
#
# word:  of positive:  19
# word:  most positive:  28
# word:  i negative:  25
# word:  ve positive:  4
# word:  seen positive:  4
# word:  quite positive:  3
# word:  long positive:  3
# ingenious
# thrillers
# words =  for
# words =  for
# words =  the
# words =  woody
# words =  allen
# words =  was
# words =  once
# words =  a
# words =  of
# words =  fresh
# words =  sometimes
# words =  funny
# words =  and
# words =  genuinely
# words =  worthwhile
# words =  hollywood
# words =  ending
# words =  is
# words =  a
# words =  experience
#
#  ['those', 'whom', 'name', 'woody', 'allen', 'was', 'once', 'guarantee', 'something', 'fresh', 'sometimes', 'funny', 'usually', 'genuinely', 'worthwhile', 'hollywood', 'ending', 'is', 'depressing', 'experience']
#
# word:  those positive:  5
# word:  woody positive:  1
# word:  allen positive:  1
# word:  was positive:  5
# word:  once negative:  1
# word:  something positive:  8
# word:  sometimes positive:  2
# word:  funny positive:  5
# word:  hollywood positive:  4
# word:  ending positive:  2
# word:  is positive:  86
# word:  depressing negative:  1
# whom
# name
# guarantee
# fresh
# usually
# genuinely
# worthwhile
# words =  of
# words =  year
# words =  s
# words =  very
# words =  best
# words =  pictures
#
#  ['this', 'year', 's', 'very', 'best', 'pictures']
#
# word:  this positive:  16
# word:  year positive:  13
# word:  s negative:  46
# word:  very positive:  4
# word:  best positive:  31
# pictures
# words =  really
# words =  really
# words =  really
# words =  good
# words =  things
# words =  can
# words =  in
# words =  packages
#
#  ['really', 'really', 'really', 'good', 'things', 'come', 'enormous', 'packages']
#
# word:  really positive:  4
# word:  really positive:  4
# word:  really positive:  4
# word:  good positive:  3
# things
# enormous
# packages
# words =  most
# words =  brilliant
#
#  ['most', 'brilliant']
#
# word:  most positive:  29
# word:  brilliant positive:  13
# words =  another
# words =  boorish
# words =  movie
# words =  from
# words =  iheardajoke
# words =  atafratparty
# words =  school
# words =  of
#
#  ['another', 'boorish', 'movie', 'the', 'iheardajoke', 'atafratparty', 'school', 'screenwriting']
#
# word:  movie positive:  43
# word:  the positive:  99
# word:  school negative:  1
# another
# boorish
# iheardajoke
# atafratparty
# screenwriting
# words =  not
# words =  because
# words =  it
# words =  full
# words =  of
# words =  discussion
# words =  points
# words =  but
# words =  it
# words =  so
# words =  that
# words =  makes
# words =  complex
# words =  politics
# words =  understandable
# words =  to
# words =  looking
# words =  for
# words =  but
# words =  entertainment
#
#  ['only', 'because', 'is', 'full', 'necessary', 'discussion', 'points', 'because', 'is', 'accessible', 'it', 'makes', 'complex', 'politics', 'understandable', 'viewers', 'looking', 'nothing', 'energetic', 'entertainment']
#
# word:  only positive:  3
# word:  because positive:  3
# word:  is positive:  87
# word:  full positive:  5
# word:  because positive:  3
# word:  is positive:  87
# word:  it positive:  11
# word:  makes positive:  5
# word:  complex positive:  2
# word:  looking positive:  3
# word:  nothing positive:  1
# word:  entertainment positive:  2
# necessary
# discussion
# points
# accessible
# politics
# understandable
# viewers
# energetic
# words =  is
# words =  pathetic
#
#  ['is', 'pathetic']
#
# word:  is positive:  89
# pathetic
# words =  it
# words =  a
# words =  and
# words =  album
# words =  you
# words =  nt
# words =  want
# words =  to
#
#  ['s', 'movie', 'an', 'album', 'wo', 'nt', 'want', 'miss']
#
# word:  s negative:  46
# word:  movie positive:  44
# word:  an positive:  19
# word:  wo positive:  1
# word:  nt positive:  13
# word:  want negative:  5
# album
# miss
# words =  juvenile
# words =  and
# words =  pedagogy
#
#  ['juvenile', 'nearxenophobic', 'pedagogy']
#
# word:  juvenile positive:  1
# word:  nearxenophobic positive:  1
# word:  pedagogy positive:  1
# words =  if
# words =  re
# words =  the
# words =  of
# words =  who
# words =  intentionally
# words =  introducing
# words =  your
# words =  kids
# words =  to
# words =  which
# words =  cause
# words =  loads
# words =  of
# words =  damage
# words =  that
# words =  and
# words =  of
# words =  analysis
# words =  could
# words =  never
# words =  fix
#
#  ['you', 're', 'kind', 'parent', 'enjoys', 'intentionally', 'introducing', 'your', 'kids', 'films', 'will', 'cause', 'loads', 'irreparable', 'damage', 'years', 'years', 'costly', 'analysis', 'could', 'never', 'fix']
#
# word:  you positive:  4
# word:  re positive:  4
# word:  kind positive:  4
# word:  your positive:  6
# word:  kids negative:  1
# word:  films positive:  18
# word:  will positive:  6
# word:  years positive:  6
# word:  years positive:  6
# word:  could positive:  4
# word:  never positive:  4
# parent
# enjoys
# intentionally
# introducing
# cause
# loads
# irreparable
# damage
# costly
# analysis
# fix
# Your method has a test accuracy of 53.5%

# %% [markdown]
# ## 6. (Optional) Did you notice something interesting?
# 1. During your design, was the training accuracy always higher than test accuracy? Can you explain why that might be true?
# 2. Was the sentiment analysis task harder than you expected? Why or why not?
# 3. Anything else you learned or feedback you may have?
#
#
# ## 7. (Optional) Further reading and exploration
# If you are interested in text data, you could look into the scikit-learn tutorial on analyzing text: https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html  We will discuss scikit-learn a little later in the semester.
